# %%
texts = []

with open('cleanedTextFileFinalDONE.txt', 'r',encoding='utf-8') as file:
    for line in file:
        texts.append(line[:-1])

# %%
def extract_rel_window(text_list, keywords_list):
    sents = []
    for sent in text_list: 
        for keyword in keywords_list:
            if keyword in sent:
                index = sent.find(keyword)
                min_idx = index
                max_idx = index
                
                while min_idx>=0 and sent[min_idx]!='.':
                    min_idx = min_idx-1
                while max_idx<len(sent) and sent[max_idx]!='.':
                    max_idx = max_idx+1
                
                # max_idx = len(sent)-1
                # if index+window_size<len(sent)-1:
                #     max_idx = index+window_size
                min_idx = min_idx + 1
                sents.append(sent[min_idx:max_idx])
    return sents

# %%
def remove_before_last_alphabet(sentence):
    # Find the index of the last alphabet
    last_alpha_index = None
    for i in range(len(sentence) - 1, -1, -1):
        if sentence[i].isalpha():
            last_alpha_index = i
            break
    
    # Remove everything before the last alphabet
    if last_alpha_index is not None:
        sentence = sentence[0:last_alpha_index+1]
    
    # Add a full stop at the end
    sentence = sentence.strip() + "."
    
    return sentence

def assign_token_ids(sent):
    # Initialize an empty list to store token information
    tokens = []

    # Iterate over each token in the sentence
    for i, (word, head, rel) in enumerate(zip(sent.words, sent.arcs, sent.rels), start=1):
        # Extract relevant information from each token
        token_info = {
            "id": i,
            "word": word,
            "head": head,
            "rel": rel,
        }
        tokens.append(token_info)

    return tokens

import nltk
nltk.download('wordnet')

from nltk.corpus import wordnet

def is_english_word(word):
    # Check if the word is in WordNet's list of English words
    return wordnet.synsets(word) != []

def transliterate_to_latin(word):
    iast_mapping = {
        'á': 'aa',
        'ñ': 'n',
        'ā': 'aa',
        'ă': 'aa',
        'ī': 'i',
        'ĭ': 'i',
        'Ś': 'sh',
        'ś': 'sh',
        'Ū': 'u',
        'ū': 'u',
        'ḍ': 'd',
        'Ḣ': '',
        'ḥ': '',
        'ṃ': 'm',
        'ṅ': 'n',
        'ṇ': 'n',
        'ṛ': 'ri',
        'ṝ': 'ri',
        'ṣ': 'sh',
        'ṭ': 't'
    }

    latin_word = ''
    for char in word:
        if char in iast_mapping:
            latin_word += iast_mapping[char]
        else:
            latin_word += char
    return latin_word
# Out:
# [nltk_data] Error loading wordnet: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>

# %%
sents = extract_rel_window(texts,["son of"])
sents = [sent.lower() for sent in sents]
sents
# Out:
# ['abhimanyu, son of arjuna and subhadrā, sister of kṛṣṇa, is an incarna tion of varcas, son of soma, wherefore he enters soma after death, after his karman has elapsed   etymology of his name  he is the vaṃśakara of the pāṇḍavas ',
#  ' droṇa, etc abhimanyu  yudhiṣṭhira supporting jayadratha karṇa has one ear cut off abhimanyu slew vṛndāraka and bṛhadbala  abhimanyu once more pierced karṇa in the ear, and slew the son of the magadha king, and aśvaketu, and the bhoja prince of mārttikāvata  the son of duḥśāsana  abhimanyu aśvatthāman   abhimanyu  śalya, who mounts another car abhimanyu slew śatruñjaya, etc',
#  'aśmaka1, a rājarṣi, son of vaśiṣṭha and madayantī, the wife of kalmāṣapāda, ',
#  'aśvaketu, son of the magadha king, killed by abhimanyu on the th day of the battle',
#  'aśvalāyana, a son of viśvāmitras, ',
#  'aśvatthāman1, son of droṇa and kṛpī     ',
#  'ādirāja, third son of avikṣit and grandson of kuru  ',
#  'adri1, son of viśvagaśva, descendant of ikṣvāku ',
#  'adṛḍha, son of jarāsandha  ',
#  'agastya1, a ṛṣi, brother of vasiṣṭha and son of mitra and varuṇa he is called maitrāvaruṇi  and kumbhayoni   he once saw his ancestors hanging in a cave, and was urged by them to procure progeny he then from the most beautiful parts of all animals created lopāmudrā and let her become the daughter of the king of vidarbha when he had married her he, in order to procure riches for her, applied successively to three kings, and then to the dānava ilvala, who shaped his own younger brother into a he goat that was digested by agastya',
#  'ahaṃyāti, a king, son of saṃyāti and father of sārvabhauma ',
#  ' arjuna withdraws his weapon but aśvatthāman is incapable of withdrawing his, as no person of uncleansed soul can bring it back, after it has once been let off, but only a brahmacārin  otherwise it strikes off his own head',
#  'aja6, son of jahnu ',
#  ' the serpent said that he was the rājarṣi nahuṣa, the son of āyu, whom agastya had cursed to become a serpent, out of compassion, however, adding to his curse that the person who would be able to answer his questions would deliver him, and that even stronger beings would, when seized by him, lose their strength',
#  'akṣīṇa, son of viśvāmitra',
#  'alolupa, son of dhṛtarāṣṭra   ',
#  'amatsyāśin, son of viśvāmitra ',
#  'amāvasu, son of purūravas and urvaśī ',
#  'ambhoruha, son of viśvāmitra',
#  ' the upādhyāya of the asuras was śukra or uśanas, son of a ṛṣi he had four sons who sacrificed for the asuras  they were brahmaloka parāyaṇāḥ',
#  'aṃśumat2, the sons son of king sagara  ',
#  'anādhṛṣṭi3, son of dhṛtarāṣṭra  ',
#  'anādhṛṣya, a son of dhṛtarāṣṭra   ',
#  'anagha6, a suparṇa, son of garuḍa ',
#  'anala1, one of the eight vasus, son of prajāpati  or dharma  and śāṇḍilī, and father of skanda',
#  'anala2, a suparṇa, son of garuḍa ',
#  'anaṅga1, son of kardama ',
#  'anenas, son of āyus and svarbhānavī ',
#  'aṅgada1, a monkey chief, son of vālin       ',
#  'aṅgada2, son of dhṛtarāṣṭra ',
#  'aṅghrika, son of viśvāmitra ',
#  ' aṅgiras also had a son, bṛhaspati knowing him the āṅgirasa to be the firstborn son of fire, the gods came and learned the matter from aṅgiras ',
#  'anila3, a suparṇa, son of garuḍa ',
#  'antevasāyin, son of a niṣādī and a cāṇḍāla, ',
#  'anu, son of yayāti  ',
#  ' said by setting free dark coloured bulls, by gifts of sesame seeds and  water on the day of new moon, and of lamps in the season of rains, men free themselves from the debt to p',
#  'anūdara, son of dhṛtarāṣṭra  ',
#  ' o sahadeva cease to go thou art my dearest child, o son of mādrī the pāṇḍavas, having consoled her, set out for the woods, and vidura led her to his house',
#  ' dhaumya, nīl descriptionwith kṛśaras, and meat, and nivāpas mixed with sesame seeds descriptionfour miles, pcr description with articles destructive of rā tena satyena, page0 b  etymologydescription, with the permission of dhṛtarāṣṭra, description, the sons and grandsons of the slain, description, jepuḥ, page0 a the son of jayadrathaorphanorphan, step description of his car, touching water, approved by gaṅgāwhile he was engaged with śikhaṇḍin and had ceased to fightdvijātipariveśakaḥpage0 b, b',
#  'anuhlāda, son of hiraṇyakaśipu  ',
#  ' the sūta ugraśravas, son of lomaharṣaṇa, had heard the mahābhārata, which had been composed by vyāsa, recited under the direction of dvai pāyana  himself by vaiśampāyana, disciple of vyāsa, at the serpent sacrifice of king janamejaya, son of parikṣit he had thereupon undertaken a pilgrimage to the tīrthas  and visited samantapañcaka  thence he came to the twelve years sattra  of  śaunaka in the naimiṣa forest, where he related the mahābhārata, beginning with the aation of viṣṇu identified with the absolute, and  a brief exposition of the creation and succession of beings from the absolute through brahmán, the prajāpatis, gods, etc n to the families of the kurus, etc mentioned in the poem',
#  'anuvinda3, son of dhṛtarāṣṭra     ',
#  'anuyāyin, a son of dhṛtarāṣṭra  ',
#  ' one should over look the wrongs inflicted by a person of superior strength, and even consider them like the acts of a child, an idiot, or one that is blind or deaf',
#  'apāntaratama, son of sarasvatī ',
#  'aparājita3, a son of dhṛtarāṣṭras   ',
#  '  gaṅgā fully related to śāntanu the reason why the brahmarṣi vasiṣṭha, the son of varuṇa, had cursed the vasus',
#  'arāṇi, a son of viśvāmitra ',
#  'ariha1, son of avācīna ',
#  'ariha2, son of devātithi ',
#  'ariha3, seems to be a son of dhrtarāṣṭras ',
#  'asamañjas1, at the request of yudhiṣṭhira, lomaśa related asa mañjas, the son of sagara and śaibyā, used to seize the children of the citizens by the throat and throw them into the river',
#  ' uddālaka prevailed upon sujātā to keep it a secret from aṣṭāvakra, who regarded uddālaka as his father and śvetaketu, the son of uddālaka, who was of the same age with himself, as his brother, until in his th year śvetaketu in anger happened to disclose the matter to him',
#  ' king parikṣit, the son of abhimanyu, was cursed and consequently struck to death by takṣaka kāśyapa was bribed to return without curing him',
#  'āsurāyaṇi, a son of viśvāmitra',
#  'aurva   son of cyavana and āruṣī and father of ṛcīka, ',
#  ' kārandhama, son of suvarcas, lived at the beginning of the tretā age, and was equal to indra, bṛhaspati, and himavat all kings were under his control he was given to sacrifices, he performed hundreds of horse sacriflces, and aṅgiras himself served as his priest, ',
#  ' about the time of king janamejaya, son of parikṣit, there was a ṛṣi named ā',
#  'āyunāthānaraṇyenakṛṣṇason of purūravas and father of nahuṣaānuśāsan',
#  ' on the next morning, at the maitra hour, in the month of kaumuda, under the constellation revatī, at the season of dews, autumn having departed, kṛṣṇa caused śinis grandson sātyaki to prepare his chariot  they yoked to it śaibya, sugrīva, meghapuṣpa, and balāhaka',
#  'bhīma1, son of dhṛtarāṣṭra ',
#  'bhīmabala2, a son of dhṛtarāṣṭra  ',
#  'bhīmaśara, a son of dhṛtarāṣṭra ',
#  'bhīmaratha1, a son of dhṛtarāṣṭra   ',
#  ' bhīma awoke and began to crush the serpents, until vāsuki came, and, informed by āryaka that he was the daughters son of āryakas daughters son, let him drink as much of their rasa  as he could',
#  'bhīmavega, son of dhṛtarāṣṭra  ',
#  'bhīṣma      in like manner bhīṣma, the son of śāntanu, was born in the womb of gaṅgā from the seed of the vasus ',
#  '  when, however, the kaliṅgas were rallied again, dhṛṣṭadyumna, with śikhaṇḍin, yudhi ṣṭhira, etc protected one of the wings of bhīmasena there was nobody on earth, save bhīma and sātyaki, who was dearer to dhṛṣṭadyumna than his very life they beheld sātyaki at a distance and that son of śini took up the wing of both bhīma and dhṛṣṭadyumna bhīma caused a bloody river to flow there',
#  ' while they, in days of old, practised penances, preparing themselves for  brahmaloka by yoga meditation, there occurred a severe drought śibis son śaibya had in former times given away a son of his as the sacrificial present to the ṛtvijes that prince now died of starvation impelled by hunger, the ṛṣis cooked his body in a vessel',
#  'bṛhadbala2, son of subala, the gāndhāra king ',
#  'bṛhadgarbha, son of śibi auśīnara ',
#  ' avikṣitsaṃvartta maruttīyason of aṅgiras and brother of saṃvarttaeḥ saṃvādaṃ maruttasya caaṅgirasaḥ putraṃ devācāryaṃpurandarau   er avarajaḥ, i',
#  'bṛhatkīrti, son of aṅgiras ',
#  'cakraka, son of viśvāmitra',
#  'cāmpeya, son of viśvāmitra',
#  'caṇḍakauśika, a muni, son of kākṣīvat ',
#  'caṇḍatuṇḍaka, a suparṇa, son of garuḍa ',
#  'candrāśva, son of kuvalāśva ',
#  'candrasena1, a prince, son of samudrasena     ',
#  'cārucitra, son of dhṛtarāṣṭra   ',
#  'cārucitrāṅgada, son of dhṛtarāṣṭra ',
#  'cāruśravas, son of kṛṣṇa and rukmiṇī',
#  'cārudeṣṇa, son of kṛṣṇa and rukmiṇī           ',
#  'cāruveśa, son of kṛṣṇa and rukmiṇī ',
#  'cāruyaśas, son of kṛṣṇa and rukmiṇī ',
#  'cirakāri, cirakārika, cirakārin, son of gautama ',
#  'cirāntaka, a suparṇa, son of garuḍa ',
#  'citra1, son of dhṛtarāṣṭra   ',
#  'citrabāhu, son of dhṛtarāṣṭra ',
#  'citrabarha, a suparṇa, son of garuḍa ',
#  'citrabarhin, son of garuḍa',
#  'citracāpa, son of dhṛtarāṣṭra ',
#  'citraka1, son of dhṛtarāṣṭra ',
#  'citraketu1, a suparṇa, son of garuḍa ',
#  'citrākṣa, son of dhṛtaraṣṭra   ',
#  'citrakuṇḍala, son of dhṛtarāṣṭra ',
#  'citrāṅga, son of dhṛtarāṣṭra ',
#  'citrāṅgada1, son of śāntanu and satyavatī       ',
#  'citrāṅgadāsuta, son of citrāṅgadā = babhruvāhana, ',
#  'citrasena1, son of dhṛtarāṣṭra                           ',
#  'citrasena2, son of the elder parikṣit ',
#  'citrasena1, son of karṇa ',
#  'citravāṇa, son of dhṛtarāṣṭra ',
#  'citravarman1, son of dhṛtarāṣṭra   ',
#  'citravarman4, son of sucitra ',
#  'citrāyudha1, son of dhṛtarāṣṭra   ',
#  'cyavana1, a ṛṣi, son of bhṛgu                  ',
#  ' asked by kuśika, cyavana explained the reason of his conduct in days past, when the gods had assembled together, he had heard brahmán say that, owing to a contention between brahman and kṣattriya energy, there would occur an intermixture in his race therefore he had resolved to exterminate the kuśikas, but had failed to find any fault with kuśika seeing the delightful palace he had created, kuśika had had a foretaste of heaven and had become desirous of the status of a brahman and the merit of penances the person who will be the third in descent from thee shall attain to the status of a brahman through the energy of the bhṛgus, thy grandson will be an ascetic endued with the splenr of fire shall set out on a tīrthayātrā',
#  'śaśabindu1, an ancient king, son of citraratha bis    king ś',
#  'śaśija, son of the moon = budha, ',
#  'śakradeva, son of the kaliṅga king ',
#  'śakrātmajātmaja, son of the son of indra = abhi manyu, ',
#  'śāktra, son of śakti = parāśara, ',
#  'śaktri, a ṛṣi, son of vasiṣṭha and father of parāśara     ',
#  'śaktrija, son of śakti = parāśara, ',
#  'śakuni1, son of the gāndhāra king subala and brother in law of dhṛtarāṣṭra                                                                  ʹ, ʹ, ʹ, ʹ, ʹ, ',
#  'śakuniputra, the son of śakuni, king of the gāndhāras ',
#  'śakunta, son of viśvāmitra',
#  'śākuntala, son of śakuntalā  = bharata, ',
#  'śala2, son of dhṛtarāṣṭra   ',
#  'śala3, son of somadatta and brother of bhūri and bhūriśravas                         ',
#  'śala4, son of king parikṣit of ayodhyā and the daughter of the frog king ',
#  'śālmali1, son of avikṣit ',
#  'śāmba1, son of kṛṣṇa and jāmbavatī          ',
#  'śambhu7, son of kṛṣṇa and rukmiṇī ',
#  'śanaiścara1, the planet saturn, son of sūrya       ',
#  'śaṅkha2, son of the matsya king virāṭa and brother of uttara          ',
#  'śaṅkhapada, son of manu svārociṣa',
#  'śaṅkukarṇa2, son of janamejaya ',
#  'śānta1, son of the vasu ahas ',
#  'śāntanu, son of pratīpa and father of bhīṣma, citrāṅgada, and vicitravīrya                   ',
#  'śānti3, son of aṅgiras',
#  'śarabha5, son of śiśupāla  ',
#  'śarāsana, son of dhṛtarāṣṭra  ',
#  'śaryāti, an ancient king, son of manu vaivasvata    ',
#  'śatānīka1, son of nakula pāṇḍava and draupadī                ',
#  'śatāyus1, son of purūravas ',
#  'śatrughna1, son of daśaratha  ',
#  'śatruñjaya2, son of dhṛtarāṣṭra   ',
#  'śatruñjaya5, son of drupada ',
#  'śatrusaha, son of dhṛtarāṣṭra   ',
#  'śauri1, son of śūra = vasudeva, ',
#  'śibi1, a king, son of uśīnara    ',
#  'śiśupāla, king of the cedis, son of damaghoṣa          ',
#  ' yudhiṣṭhira caused his brothers to perform the funeral rites of śiśupāla, the son of damaghoṣa then he, with all the kings, installed the son of śiśupāla in the sovereignty of the cedis v',
#  'śilāyūpa, a son of viśvāmitra',
#  'śīrṣin, a son of viśvāmitra',
#  'śita, a son of viśvāmitra',
#  ' skanda, the son of agnirudreṇa śukram utsṛṣṭaṃ tac chvetaḥ parvato bhavatanupraviśya rudreṇa vahniṃ jāto hy ayaṃ śiśuḥ, i',
#  'śrīmat1, son of nimi ',
#  'śrutakarman1, son of sahadeva and draupadī        ',
#  'śrutakarman2, son of arjuna and draupadī  ',
#  'śrutakarman3, son of dhṛtarāṣṭra ',
#  'śrutakīrti, son of',
#  'śrutānta, son of dhṛtarāṣṭra ',
#  'śrutarvan2, son of dhṛtarāṣṭra  ',
#  'śrutasena3, son of sahadeva and draupadī    ',
#  'śṛṅgin1, son of śamīka    ',
#  'śuci8, a son of vicvāmitra',
#  'śuci1, a son of bhṛgu',
#  'śuka1, son of vyāsa     ',
#  'śuka4, a gandhāra warrior, the son of subala ',
#  'asureṣu, vidura excelled cukra in intelligencepage2 a son of kavicukrenośanasāśukraḥuśanasaṃuśanasaḥmaharṣiḥbhṛguśreṣṭhaḥuśanasaḥuśanasaḥuśanasāa śloka recited by him in order to induce the asuras to aban jambha, is quotedśukrasyauśanāḥ kāvyaḥ, on meruhad performed austerities at kapālamocanaamong the ṛṣis who surrounded bhīṣma as he lay on his arrow bedwent to heavenuśanāḥ second son of kavibhārgavaḥsenāpatir abhūt',
#  'śunaḥśepha, son of ṛcīka ',
#  'śūra3, son of īlina ',
#  'śvetaketu1, a muni, son of uddālaka ',
#  'śyāmāyana, son of viśvāmitra',
#  'śyenajit1, son of dala ',
#  'daśajyotis, son of subhrāj ',
#  'daityadvīpa, a suparṇa, son of garuḍa ',
#  'dakṣa2, a suparṇa, son of garuḍa ',
#  'dala, son of king parikṣit of ayodhyā, and suśobhanā the daughter of the frog king ',
#  'dama1, son of bhīma, the vidarbha king ',
#  'damana3, son of the vidarbha king bhīma ',
#  'daṇḍadhāra2, son of dhṛtarāṣṭra  ʹ, ',
#  'daṇḍin1, son of dhṛtarāṣṭra ',
#  'dānta1, a son of the vidarbha king bhīma ',
#  'darpa, son of adharma and śrī ',
#  'dāruṇa1, a suparṇa, son of garuḍa ',
#  'dauḥśāsani, patron the son of duḥśāsana dhārtarāṣṭra       ',
#  'devāpi, son of pratīpa     ',
#  'devarāta2, a muni, son of viśvāmitra  ',
#  ' uśanas cursed yayāti to be overcome by decrepitude, yet with the permission of trans ferring it to someone else, and he added that that son of yayāti who would give him his own youth should succeed yayāti on the throne, etc     ',
#  'dhanurdhara1, a son of dhṛtarāṣṭra ',
#  'dhanurgraha, a son of dhṛtarāṣṭra  ʹ, ',
#  'dhanurgrāha, a son of dhṛtarāṣṭra ',
#  ' examined janakauttaṅkathe eldest son of kṛṣṇa nakulākhyanain the shape of a brahman dh',
#  'dharmanetra, grandson of the elder dhṛtarāṣṭra ',
#  'dhruva2, son of nahuṣa ',
#  'dhṛṣṇu1, son of manu vaivasvata ',
#  'dhṛṣṇu2, son of kavi',
#  'dhṛṣṭadyumna, son of the pāñcāla king drupada and brother of draupadī                                                  ʹ, ʹ, ʹ, ',
#  'dhṛṣṭaketu2, king of the cedis, son of śiśupāla      ',
#  'dhṛtarāṣṭra1, son of vyāsa with ambikā, the wi of vicitravīrya                                                                                                                                ',
#  'dhṛtarāṣṭra4, a king, son of the elder janamejaya ',
#  'dhundhu1, an asura, son of madhu and kaiṭabha',
#  'diśācakṣu, a suparṇa, the son of garuḍa ',
#  'dīpaka, a suparṇa, the son of garuḍa ',
#  'dīrghabāhu, son of dhṛtarāṣṭra     ',
#  'dīrghajihva, an asura, son of danu  ',
#  'dīrghalocana, son of dhṛtarāṣṭra     ',
#  'dīrgharoma, son of dhṛtarāṣṭra ',
#  'dīrghāyus, son of aśyutāyus ',
#  'divākara1, a suparṇa, the son of garuḍa ',
#  'diviratha1, the son of bhumanyu ',
#  'diviratha2, the son of dadhivāhana',
#  'divodāsa, king of the kāśis, son of bhīmasena or sudeva   ',
#  ' koṭikāsya introduced himself to draupadī and showed her the trigarta king kṣemaṅkara, and the son of the king of the kulindas, and the son of subala  of the race of ikṣvāku he said that jayadratha was there at the head of, chariots, etc followed by twelve sauvīra princes as his standard bearers, and his brothers  ',
#  'draviṇa, son of the vasu dhara ',
#  'droṇa, the preceptor of the dhārtarāṣṭras and the pāṇḍavas, dhṛṣṭadyumna, etc son of bharadvāja, husband of kṛpī, and father of aśvatthāman     ',
#  'droṇa2, a śārṅgaka, a son of mandapāla and jaritā ',
#  'druhyu1, son of yayāti and śarmiṣṭhā     ',
#  'druhyu2, son of matināra ',
#  'drupada, king of the pāñcālas, son of pṛṣata, father of dhṛṣṭadyumna, śikhaṇḍin, draupadī, etc    ',
#  'dṛḍha1, son of dhṛtarāṣṭra ',
#  'dṛḍhāśva, son of kuvalāśva ',
#  'dṛḍhahasta, a son of dhṛtarāṣṭra  ',
#  'dṛḍhakṣatra, a son of dhṛtarāṣṭra  ',
#  'dṛḍharatha1, a son of dhṛtarāṣṭra  ',
#  'dṛḍharathāśraya, a son of dhṛtarāṣṭra ',
#  'dṛḍhasandha, a son of dhṛtarāṣṭra  ',
#  'dṛḍhasyu, a ṛṣi, son of agastya and lopāmudrā ',
#  'dṛḍhavarman, a son of dhṛtarāṣṭra  ',
#  'dṛdhāyu, son of purūravas and urvaśī ',
#  'dṛḍhāyudha, a son of dhṛtarāṣṭra ',
#  'duḥśala, a son of dhṛtarāṣṭra    ',
#  'duḥśāsana, a son of dhṛtarāṣṭra                                                                   ʹ, ʹ, ',
#  'duḥsaha1, son of dhṛtarāṣṭra              ',
#  'durādhana, a son of dhṛtaṛāṣṭra ',
#  'durādhara, a son of dhṛtarāṣṭra ',
#  'durdhara1, a son of dhṛtarāṣṭra  ',
#  'durdharṣa1, a son of dhṛtarāṣṭra    ',
#  'durdharṣaṇa, a son of dhṛtarāṣṭra ',
#  'durjaya2, son of śāradaṇḍāyanī',
#  'durjaya3, son of dhṛtarāṣṭra     ',
#  'durmada, son of dhṛtarāṣṭra      ',
#  'durmarṣaṇa1, son of dhṛtarāṣṭra                ',
#  'durmukha1, son of dhṛtarāṣṭra                    ',
#  'durvigāha, a son of dhṛtarāṣṭra ',
#  'durvimocana, a son of dhṛtarāṣṭra   ',
#  'durvirocana, a son of dhṛtarāṣṭra ',
#  'durviṣaha1, a son of dhṛtarāṣṭra        ',
#  'duryodhana1, the eldest son of dhṛtarāṣṭra and gāndhārī, and the enemy of the pāṇḍavas      ',
#  'duṣkarṇa, a son of dhṛtarāṣṭra    ',
#  'duṣparājaya, a son of dhṛtarāṣṭra ',
#  'duṣpradharṣa, a son of dhṛtarāṣṭra   ',
#  'duṣpradharṣaṇa, a son of dhṛtarāṣṭra    ',
#  'duṣpraharṣa, a son of dhṛtarāṣṭra ',
#  'duṣyanta2, son of ajamīḍha ',
#  ' therefore one evening the ṛṣi baka dālbhya represented to yudhiṣṭhira that the kṣatriya should always consult with a brahman, as did the asura king bali, the son of virocana, who went to no other tīrtha than the brahmans, and then had all his wishes gratified, but who met with destruction when he began to act unjustly towards them',
#  ' among the kings and princes who flocked to droṇa by thousands to learn the dhanurveda was e the son of the niṣāda king hiraṇyadhanus',
#  'gādhi or gādhin, a king of kānyakubja, the son of kuśika and the father of viśvāmitra and satyavatī    ',
#  'gāndhārarāja4 = the son of śakuni, ',
#  'gāndhārarājaputra = the son of śakuni, ',
#  ' sagara was greeted by all the gods and converted the sea into a son of himself, and after a long reign placed his grandson on the throne and ascended to heaven',
#  'gardabhi, a son of viśvāmitra',
#  'garuḍa, the son of kaśyapa and vinatā, the vehicle of viṣṇu, or the emblem of his flagstaff  ',
#  'gavākṣa2, a gandhāra warrior, son of subala and brother of śakuni  ',
#  'gaya1, an ancient king, son of amūrtarayas       ',
#  'ghaṭotkaca, a rākṣasa, son of hiḍimbā and bhīmasena pāṇḍava                             g',
#  'ghora2, son of aṅgiras',
#  ' his brothers, śatānīka and madirākṣa, and the king himself, and sūryadatta and śaṅkha, the eldest son of virāṭa, put on their coats of mail',
#  'gomukha2, the son of mātali ',
#  'gopati5, a son of śibi',
#  ' the jackal mentioned that by rāmas  slaying the śūdra named śambuka, a brahmaṇa child was restored to life similarly the son of r',
#  'gurubhāra, a suparṇa, the son of garuḍa ',
#  'haihaya1, a son of vatsa',
#  'haṃsa2, a gandharva king, the son of ariṣṭā ',
#  '  hanūmat said that he was the son of vāyu with the wife of keśarin, and the friend of the suns son sugrīva, who, together with śakras son vālin, used to be waited upon by all monkeys further, that sugrīva had been driven out by his brother, and dwelt for a long time with hanūmat at ṛṣyamūka, when rāma dāśarathi, who was viṣṇu in human shape, with his wife and younger brother resided in the daṇḍaka forest, and the rākṣasa rāvaṇa carried away sītā, rāmas queen, from janasthāna, assisted by the rākṣasa mārīca, in the form of a deer marked with gems and gold ',
#  'hanumat or hanūmat, name of a monkey, the son of vāyu               ',
#  'hari3, a suparṇa, the son of garuḍa ',
#  'hari4, the son of akampana  ',
#  'hari5, an asura, the son of tārakākṣa ',
#  'harṣa, a son of dharma ',
#  'hastin1, a son of the elder dhṛtarāṣṭra ',
#  'hastin2, a son of suhotra ',
#  'haviḥśravas, a son of the elder dhṛtarāṣṭra ',
#  'hemavarṇa1, a suparṇa, the son of garuḍa ',
#  'hemavarṇa2, the son of rocamāna ',
#  'hiraṇyākṣa2, a son of viśvāmitra',
#  'īśvara7, a son of pūru ',
#  'ikṣvāku1, an ancient king, the son or great grandson of manu vaivasvata                  ',
#  'ikṣvākunandana1  = lakṣmaṇa, the son of daśaratha, ',
#  'ikṣvākunandana2 = rāma, the son of daśaratha, ',
#  ' hari, the son of akampanapratimavikramāḥfather of arjunasūryaguṇodayaṃ, sc',
#  'indrābha, son of the elder dhṛtarāṣṭra ',
#  'indrajit, a rākṣasa, son of rāvaṇa   ',
#  ' sañjaya commemorated how kṛṣṇa, dhṛṣṭadyumna, virāṭa, dhṛṣṭa ketu, and the kaikeyas had visited the pāṇḍavas in the kāmyaka wood, whose conversations sañjaya had learnt through spies and formerly told dhṛtarāṣṭra, sañjaya further related that kṛṣṇa had consented to become the  charioteer of arjuna  and to assist the pāṇḍavas in the battle, together with rāma, akrūra, gada, śāmba, pradyumna, āhuka, dhṛṣṭadyumna, and the son of śiśupāla, and yuyu dhāna, and the kaikeya and pāñcāla princes and the matsya king, and kṛṣṇa had declared that yudhiṣṭhira should, along with his brothers living at hāstinapura, rule the earth ',
#  ' b  bhīṣma said once a brahman obtained a son named mataṅga, who, though procreated by a person of a different order, had, however, the rites of infancy and youth performed according to the ordinances laid n for brahmans',
#  'indrasena1, a son of the elder parikṣit ',
#  'indrasena2, the son of nala and damayantī   ',
#  'irāvat, a son of arjuna pāṇḍava    ',
#  'jābāli, a ṛṣi, son of viśvāmitra ',
#  'jaitra, a son of dhṛtarāṣṭra ',
#  'jalasandha2, a son of dhṛtarāṣṭra     ',
#  'jaleyu, a son of raudrāśva ',
#  'jamadagni, a ṛṣi, the son of ṛcīka and satyavatī and the father of rāma1     ',
#  ' b  the son of j',
#  'jāmbūnada, son of the elder janamejaya',
#  'janamejaya1, son of parikṣit and mādravatī, and the husband of vapuṣṭamā at his snake sacrifice vaiśampāyana recited the mhbhr',
#  'janamejaya4, son of kuru ',
#  'janamejaya5, son of the elder parikṣit ',
#  'janamejaya6, son of pūru ',
#  'jaṅghāri, a son of viśvāmitra',
#  'jantu, son of king somaka ',
#  ' b  a brahman, who was a reciter, conversant with the six aṅgas, of the kuśika race and son of pippalāda, acquired spiritual insight into the aṅgas at the foot of himavat he was devoted to the vedas silently reciting gāyatrī, he practised austerities for, years in order to attain to bráhman',
#  'jarāsandha1, king of the māgadhas, son of bṛhadratha            ',
#  'jarāsandha2, a son of dhṛtarāṣṭra  ',
#  ' stopping on a level plain outside the town, he was aed by the citizens, and he installed sahadeva, the son of jarāsandha, in the sovereignty of the magadhas',
#  'jaritāri, the eldest son of mandapāla and jaritā ',
#  'jaya1, a son of dhṛtarāṣṭra, or an adherent of duryodhana             ',
#  'jayadratha1, king of the sindhus, son of vṛddhakṣatra                      ',
#  ' wondered vīradhanvan was slain by dhṛṣṭaketu durmukha   sahadeva dur mukha mounted the chariot of niramitra, who was slain by sahadeva nakula  vikarṇa, whom he vanquished vyāghradatta   sātyaki, who slew him the magadhas  sātyaki, who nearly exterminated them the kurus were routed droṇa  sātyaki  bhūriśravas  the draupadeyas śatānīka, etc bhūriśravas, who was slain by the son of sahadeva rā',
#  'jayanta1, son of indra and śacī  ',
#  'jayasena2, a son of dhṛtarāṣṭra ',
#  'jayatsena1, a māgadha king, the son of jarāsandha               ',
#  'jayatsena2, son of sarvabhauma and sunandā kaikeyī ',
#  'jayatsena4, a son of dhṛtarāṣṭra   ',
#  'jitāri, son of avikṣit and grandson of kuru ',
#  'jyotis1, son of the vasu ahas ',
#  'kaca, a brahman, the son of bṛhaspati',
#  'kāśin, a son of kavi',
#  'kāśyapa, a ṛṣi and prajāpati, son of marīci',
#  ' then śiva with his bow and arrows, in the guise of a kirāta, accompanied by umā in the guise of a kirāta woman, by merry spirits, and thousands of women, approached arjuna as he was about to kill mūka, a son of danu, who in the form of a boar would have killed arjuna',
#  'kākutstha2  = rāma, the son of daśaratha, ',
#  'kākutstha3 = lakṣmaṇa, the son of daśaratha, ',
#  'kālapatha, a son of viśvāmitra ',
#  'kālikeya, a kuru warrior, son of subala ',
#  'kaṃsa, son of ugrasena, king of mathurā, enemy of kṛṣṇa       ',
#  'kanakadhvaja, a son of dhṛtarāṣṭra   ',
#  'kanakāṅgada, a son of dhṛtarāṣṭra ',
#  'kanakāyu, a son of dhṛtarāṣṭra ',
#  'kapota1, a suparṇa, son of garuḍa ',
#  'karakāyu, a son of dhṛtarāṣṭra ',
#  'kārīṣi, a son of viśvāmitra',
#  'karmin, a son of śukra  ',
#  'karṇa1, son of sūrya with kuntī, ated by the sūta adhi ratha and his wife rādhā, and the counsellor of duryodhana     ',
#  'karṇa2, son of dhṛtarāṣṭra   ',
#  ' rāma gave the dhanurveda to karṇa, whom not think to have been born in the sūta order, but to be the son of a god, born in the kṣatriya order and abaned in infancy ',
#  'kārūṣa1, son of manu vaivasvata ',
#  'kavacin, a son of dhṛtarāṣṭra   ',
#  'kavi4, a son of kavi1',
#  'kāvya1, a son of kavi1',
#  ' rudra then gave the sword to viṣṇu, viṣṇu to marīci, marīci to the maharṣis, the maharṣis to vāsava, mahendra  to the lokapālas, the lokapālas to manu  the son of sūrya',
#  'khanīnetra, a king, son of viviṃśa and father of suvarcas',
#  'khara, a rākṣasa, son of viśravas   ',
#  'krātha1, son of the elder dhṛtarāṣṭra ',
#  'krātha4, son of dhṛtarāṣṭra ',
#  'krathana3, son of dhṛtarāṣṭra ',
#  'kratu1, a ṛṣi, son of brahmán       ',
#  'kṛśa1, a son of a ṛṣi ',
#  'kṛkaṇeyu, son of raudrāśva ',
#  'kṛpa, a brahman, son of śaradvat and brother of kṛpī                         ',
#  'kṛṣṇa1, son of vasudeva and devakī, husband of rukmiṇī, etc and father of pradyumna, śāmba, etc a prince of the dāśārhas, considered as an avatāra of viṣṇu, the supreme god                  ',
#  'kṛtavarman, a vṛṣṇi prince, son of hṛdika                                           ʹ, ʹ, nārāyaṇāvaśeṣaiḥ, sc',
#  'kṣatradeva, son of śikhaṇḍin        ',
#  'kṣatradharman, son of dhṛṣṭadyumna       ',
#  'kṣemamūrti, a son of dhṛtarāṣṭra ',
#  'kuśāmba, son of vasu uparicara ',
#  'kukṣi2, b, diśāṃ pālāya, son of raibhya',
#  'kumāra3, a suparṇa, son of garuḍa ',
#  'kumuda4, a suparṇa, son of garuḍa ',
#  'kuṇḍa1, a son of dhṛtarāṣṭra ',
#  'kuṇḍabheda, a son of dhṛtarāṣṭra ',
#  'kuṇḍabhedin, a son of dhṛtarāṣṭra     ',
#  'kuṇḍaśāyin, a son of dhṛtarāṣṭra ',
#  'kuṇḍāśin, a son of dhṛtarāṣṭra ',
#  'kuṇḍadhāra1, a son of dhṛtarāṣṭra  ',
#  'kuṇḍaja, a son of dhṛtarāṣṭra ',
#  'kuṇḍaka, a son of dhṛtarāṣṭra ',
#  'kuṇḍalin1, a suparṇa, son of garuḍa ',
#  'kuṇḍalin2, a son of dhṛtarāṣṭra ',
#  'kuṇḍika, son of dhṛtarāṣṭra4 ',
#  'kuṇḍina1, son of dhṛtarāṣṭra4 ',
#  'kuṇḍodara2, a son of dhṛtarāṣṭra1 ',
#  'kuṇḍodara3, son of janamejaya5 ',
#  '  śūra  gave his daughter pṛthā as daughter to kuntibhoja, the son of his paternal aunt, who was without offspring',
#  'kūrcāmukha, a son of viśvāmitra',
#  'kuru1, an ancient king, the son of saṃvaraṇa and the ancestor of the kurus      ',
#  'lakṣmaṇa1, son of daśaratha and sumitrā and brother of rāma                   ',
#  'lakṣmaṇa2, son of duryodhana dhārtarāṣṭra             ',
#  'lilāḍhya, a son of viśvāmitra',
#  'madhuparka, a suparṇa, son of garuḍa ',
#  'māgadha6 = jayatsena, son of jarāsandha, ',
#  'māgadha7 = meghasandhi, the son of sahadeva, ',
#  'māgadha8 = sahadeva, son of jarāsandha, ',
#  ' he then wished to be born as a son of pratīpa',
#  'mahodara3, a son of dhṛtarāṣṭra   ',
#  'malaya3, a suparṇa, son of garuḍa ',
#  'mānada1, son of dhṛṣṭadyumna ',
#  'mandāra, son of hiraṇyakaśipu',
#  'māndhātṛ, an ancient king, son of yuvanāśva         ',
#  ' having once observed a fast, he entered the hermitage of bhṛgu, while the great ṛṣis were asleep, and drank a jar of water, which the son of bhṛgu, after having performed severe austerities, had destined to be drunk by yuvanāśvas queen in order that she should bear him a son, who by his bravery might send even indra to the abode of yama',
#  ' was the son of mātariśvan and sukanyā, ',
#  'manojava1, son of the vasu anila and śivā ',
#  '  kaśyapa, the son of marīci, begat upon  the daughter of dakṣa  the ādityas  and vivasvat ',
#  'mārgamarṣi, a son of viśvāmitra',
#  'marīci1, a ṛṣi, son of brahmán and father of kaśyapa      ',
#  '  when the pāṇḍavas were dwelling at that very place, there set in the season of the rains ',
#  'mārutantavya, a son of viśvāmitra',
#  'marutta, an ancient king, son of avikṣit bis         m the son of avikṣit, in order to compete with bṛhaspati, caused saṃvarta  to officiate at his sacrifice',
#  ' mātali wished to get for his son in law the nāga sumukha of airāvatas race, the son of cikura, and the grandson of āryaka kauravya and the daughters son of vāmana ',
#  'mātariśvan2, a suparṇa, son of garuḍa ',
#  'matsya1, a king, son of vasu uparicara',
#  ' arjuna became very cheerless he escorted the remnant of the cavalcade to kurukṣetra he established the son of kṛtavarman in the city of mārttikāvata with the remnant of the women of the bhoja king the remainder, with children and old men and women, at indraprastha, with vajra as their ruler the son of yuyudhāna  on the banks of the sarasvatī the wis of akrūra, notwithstanding the entreaties of vajra, entered the woods rukmiṇī, etc ascended the funeral pyre satyabhāmā and the other wives of kṛṣṇa entered the woods in order  to practise penances in the contemplation of hari going beyond himavat, they took up their abode in kalāpa grāma',
#  'medhāvin1, son of bāladhi',
#  'meghasandhi2, king  in rājagṛha, son of sahadeva ',
#  'meṣahṛt, a suparṇa, son of garuḍa ',
#  ' yudhiṣṭhira inquired about the reason of kṛṣṇas assuming the form of an animal',
#  ' its disadvantages while reaping the fruit of his acts a person cannot be engaged in any others, for this world is one of acts, the other one of fruition after one has entirely exhausted his merit, he is subject to fall he is then stupefied and agitated by emotions, and when the garlands of those who are to fall fade away, fear invades their hearts but by reason of their merits they take birth among men, and then they attain to high fortune and happiness, while, if one cannot acquire knowledge here, he comes by an inferior birth',
#  'muni1, son of ahar ',
#  'muni2, son of kuru ',
#  'muṣala, son of viśvāmitra',
#  'nābhāgāriṣṭa, son of manu vaivasvata ',
#  'nācika, a son of viśvāmitra',
#  'nāciketa, a ṛṣi, son of uddālaki    ',
#  'nāḍījaṅgha, a crane, son of kaśyapa ',
#  'nāgāśin, a suparṇa, son of garuḍa ',
#  'nāgadatta, a son of dhṛtarāṣṭra   ',
#  'nahuṣa2, an ancient king, son of āyus and father of yayāti, etc for some time king of the gods, but cursed and born as a serpent  ',
#  'naikadṛś, son of viśvāmitra',
#  'nala1, king of the niṣadhas, son of vīrasena, and husband of damayantī                        ',
#  'nalakūbara, a son of kubera  ',
#  ' bṛhadaśva said the niṣadha king nala, the son of vīrasena, was above all kings, etc and fond of dice',
#  'nanda1, a son of dhṛtarāṣṭra    ',
#  'nandaka1, a son of dhṛtarāṣṭra   ',
#  'nārada1, a devarṣi, son of parameṣṭhin, often mentioned together with gandharvas and therefore presumably himself a gandharva',
#  'nārada3, a son of viśvāmitra',
#  'nāradin, a son of viśvāmitra',
#  'naraka1, an asura, son of bhūmi  and slain by kṛṣṇa  ',
#  'nārāyaṇa, name of an ancient god or ṛṣi, the son of dharma, commonly connected with nara, but also the name of the supreme god, from whom the son of dharma was born          ',
#  ' bhīṣma said  heard it from my father that in the kṛta age, during the epoch of manu svāyambhuva, the eternal nārāyaṇa, the soul of the universe, took birth as the son of dharma in a quadruple form as nara, nārāyaṇa, hari, and the self existent  kṛṣṇa',
#  'nariṣyanta or nariṣyat, son of manu vaivasvata',
#  'navatantu, son of viśvāmitra',
#  'niśākara2, a suparṇa, son of garuḍa',
#  'nimi2, son of dattātreya and father of śrīmat ',
#  'nimiṣa1, a suparṇa, son of garuḍa ',
#  'niramitra1, son of nakula ',
#  'niṣādarājan = the son of ekalavya, ',
#  'niṣadha1, son of the elder janamejaya ',
#  'niṣaṅgin, a son of dhṛtarāṣṭra   ',
#  'ogharatha, son of oghavat2',
#  'pāśin, a son of dhṛtarāṣṭra  ',
#  'padāti, son of the elder janamejaya ',
#  'padmaketana, a suparṇa, son of garuḍa ',
#  'padmaṇābha2, a son of dhṛtarāṣṭra ',
#  'paṇḍita1, a son of dhṛtarāṣṭra ',
#  'paṇḍitaka, a son of dhṛtarāṣṭra = paṇḍita  ',
#  'pāṇḍu, son of vyāsa by ambālikā, the wi of vicitravīrya husband of kuntī and mādrī and father of the five pāṇḍavas            ',
#  'pāṇḍu2, son of the elder janamejaya ',
#  'paṅkajit, a suparṇa, son of garuḍa, ',
#  'parāśara1, a ṛṣi, son of śakti and adṛśyantī, and father of vyāsa    ',
#  'parameṣṭhin5, son of ajamīḍha ',
#  'parāvasu, a brahman, son of raibhya and brother of arvāvasu   ',
#  'pāribarha, a suparṇa, son of garuḍa ',
#  'parikṣit or parīkṣit, son of abhimanyu and uttarā, and father of janamejaya ',
#  'parikṣit2 or parīkṣit, son of avikṣit ',
#  'parīkṣit, son of anaśvan ',
#  'parvata1, a devarṣi, son of nāradas sister, often mentioned together with gandharvas            ',
#  ' she chose satyavat, the son of the śālva king dyumatsena, who had been blinded and deprived of his king and lived as an ascetic in the forest',
#  '  when janamejaya, the son of parikṣit, with his brothers śrutasena, ugrasena, and bhīmasena was attending his long sacrifice at kurukṣetra, his brothers beat an offspring of saramā',
#  'payasya, son of aṅgiras',
#  'pradyumna, son of kṛṣṇa and rukmiṇī           ',
#  ' virocana, the son of the king of the daityas p for the sake of obtaining a bride, quarrelled with sudhanvan āṅgirasa, and they mutually wagered their lives as to who was superior, and made p',
#  ' then he explained the marks of a wise man and of a fool, quoting bṛhaspatis answer to indra, and alluding to the conversation between sudhanvan and asurendra  in relation to the son of the latter ',
#  'pramatha, a son of dhṛtarāṣṭra ',
#  'pramāthin1, a son of dhṛtaraṣṭra  ',
#  'prasandhi, son of manu',
#  'prasena, son of karṇa ʹ, ',
#  'pratardana1, king of the kāśis, son of divodāsa     ',
#  'prativindhya1, son of yudhiṣṭhira and draupadī              ',
#  'pratyagraha, son of vasu uparicara ',
#  'pravasu, son of īlina ',
#  'pravīra, son of pūru ',
#  'pūru1, an ancient king, son of yayāti',
#  'purukutsa, an ancient king, son of māndhātṛ  ',
#  'purumitra, a son of dhṛtarāṣṭra             ',
#  'purūravas, an ancient king, son of ilā, and husband of urvaśī ',
#  ' bharata  obtained from bharadvāja a son of the name bhumanyu, who became his heir apparent',
#  'puṣkara3, son of varuṇa  ',
#  ' janaka became freed from grief enjoy the earth, o son of kuntī ',
#  ' as he was childless he repaired to the ṛṣi caṇḍa kauśika, the son of kākṣīvat gautama, who was sitting under a mango tree',
#  'rāma1, son of jamadagni and reṇukā, otherwise called paraśu rāma, which name, however, s not occur in the text of the mhbhr',
#  'rāma2 dāśarathi, king of ayodhyā, son of daśaratha and husband of sītā bis                                   ',
#  ' ṛcīka destined a certain portion of the sacrificial food  for satyavatī, which would give her a son of great wis, the foremost of brahmans and another  for her mother, which would give her for a son an invincible kṣatriya',
#  'rantideva, an ancient king, son of saṅkṛti      ',
#  'raudra4, son of śukra ',
#  'raudrakarman, a son of dhṛtarāṣṭra   ',
#  'rāvaṇa, king of the rākṣasas on laṅkā, son of viśravas                               ',
#  'ravi3, a son of dhṛtarāṣṭra ',
#  'ruci1, a son of viśvāmitra',
#  'ruciparvan, a pāṇḍava warrior, son of kṛti ',
#  'rukmaratha1, son of śalya    ',
#  'rukmin, king of bhojakaṭa, son of bhīṣmaka, and brother of rukmiṇī    ',
#  'rumaṇvat, son of jamadagni ',
#  'rūpina, son of ajamīḍha and keśinī ',
#  'ṛcīka1, a form or son of vivasvat  ',
#  'ṛcīka3, son of bhūmanyu ',
#  'ṛcīkanandana, son of ṛcīka = rāma jāma dagnya, ',
#  'ṛkṣa1, a prince, son of ajamīḍha ',
#  'ṛkṣa2, a prince, son of ariha ',
#  'ṛṣyaśṛṅga, a muni, son of vibhāṇḍaka  ',
#  'sada, a son of dhṛtarāṣṭra ',
#  ' nārada told it to s who sent for aṃśumat, the son of his son asamañjas, whom he had abaned according to his duty and for the good of the citizens, ',
#  'saha1, a son of dhṛtarāṣṭra   ʹ, ',
#  ' pro ceeded against the south and vanquished the śūrasenas, etc then the son of jambhaka, etc then bhīṣmaka, etc',
#  'sahadeva2, king of the magadhas, son of jarāsandha     ',
#  'sahasravāc, a son of dhṛtarāṣṭra ',
#  'saindhavāyana, a son of viśvāmitra',
#  'sālaṅghāyana, a son of viśvāmitra',
#  'sama1, a son of dhṛtarāṣṭra    ',
#  ' in days of old bhūtakarman sabhāpati  nakulas son śatānīka bhūtakarman was slain by śatānīka viviṃśati  sutasoma bhīmaratha  slew śālva citra senas son  śrutakarman prativindhya  aśvatthāman the son of duḥśāsana  śrutakīrti  lakṣmaṇa   paṭaccarahantṛ vikarṇa   śikhaṇḍin aṅgada  uttamaujas durmukha  purujit karṇa  the five kekaya brothers durjaya  jaya  vijaya   nīla  the kāśi king  jayatsena kṣemadhūrti  bṛhanta  sātyaki the cedi king  ambaṣṭha kṛpa  vārdhakṣemi soma dattas son  maṇimat vṛṣasena   pāṇḍya ghaṭotkaca  alambuṣa  duryodhana  bhīmasena the aṅga king    bhīma slew him, and his divisions fied the prāgjyotiṣa king   bhīma  bhīma escaped from the elephant, but was supposed to have been slain yudhiṣṭhira   bhagadatta  the daśārṇa king   bhagadatta bhagadatta  yuyudhāna bhagadatta destroyed the pāṇḍava troops bhīma  bhagadatta, whose elephant frightened bhīmas steeds, that bore bhīma away ruciparvan   bhagadatta, who slew him abhimanyu, etc bhagadattas elephant yuyutsu had his steeds and charioteer trod n and fled duryodhana  abhimanyu arjuna, etc',
#  'saṃhanana, son of manasyu ',
#  'saṃvaraṇa, a king, son of ṛkṣa, husband of tapatī, and father of kuru ',
#  'saṃvarta1, a brahmarṣi, son of aṅgiras      ',
#  'saṃyāti1, son of nahuṣa ',
#  'sana, a mind born son of brahmán',
#  'sanaka, a mind born son of brahmán',
#  'sanandana, a mind born son of brahmán',
#  'sanātana2, a mind born son of brahmán',
#  'sanatkumāra, a ṛṣi, son of brahmán         ',
#  'sañjaya1, a sūta, son of gavalgaṇa   ',
#  'sañjaya4, a sauvīra king, son of vidulā ',
#  'sannateyu, son of raudrāśva ',
#  'saptarāva, a suparṇa, son of garuḍa ',
#  'sāraṇa, a vṛṣṇi, son of vasudeva          ',
#  'sārasa, a suparṇa, son of garuḍa ',
#  'sārasvata, a ṛṣi, son of dadhīca and sarasvatī   ',
#  'sārasvata2, a ṛṣi, son of atri   ',
#  'sārisṛkka  or sārisṛkva, a śārṅgaka, son of mandapāla ',
#  'sarpānta, a suparṇa, son of garuḍa ',
#  'sattva, a son of dhṛtarāṣṭra ',
#  'satyajit, a pāñcāla, son of drupada        ',
#  'satyaka, a vṛṣṇi, son of śini and father of sātyaki      ',
#  'sātyaki, a vṛṣni, properly named yuyudhāna, son of satyaka and grandson of śini',
#  'satyasandha1, son of dhṛtarāṣṭra  ',
#  'satyasandha4, son of karṇa  ',
#  'satyasena2, a son of karṇa  ',
#  'satyavat1, son of dyumatsena and husband of sāvitrī   ',
#  'satyavrata2, a son of dhṛtarāṣṭra         ',
#  'saubhara, name of a fire, son of varcas ',
#  ' kṛṣṇa related when śiśupāla, the son of damaghoṣa, had been slain, his brother, the mārttikā vata king śālva, in order to avenge him, came to dvārakā in the saubha, who moved at will and slew many of the vṛṣṇis, and sought for kṛṣṇa desiring to kill him',
#  'savana, a son of bhṛgu',
#  'sayana, son of viśvāmitra',
#  'senānī, a son of dhṛtarāṣṭra ',
#  'senāpati1, a son of dhṛtarāṣṭra  ',
#  ' he and lakṣmaṇa lay n on the seashore, the ocean appeared to him in a vision and said  also have sprung from the race of ikṣvāku the monkey nala is a son of tvaṣṭr, whatever he will throw into my waters will support',
#  'ṣaṇḍa, a son of dhṛtarāṣṭra ',
#  'sindhudvīpa, an ancient king, son of jahnu ',
#  'skanda1, the senāpati of the gods, son of agni and svāhā, reared by the kṛttikās, armed with a dart  and having a peacock  for his device',
#  ' skanda is called the son of rudra because agni is called rudra by brahmans, and because he was pro duced by rudra entering fire, and because he was honoured by rudra before all the gods, and because the śveta mountain, where he was reared by the kṛttikās, was formed of rudras semen virile',
#  ' mārkanḍeya promised to tell the story of kārttikeya, the son of adbhuta, begotten of the wives of the brahmarṣis',
#  'somabhojana, a suparṇa, son of garuḍa ',
#  'somaśravas, a brahman, son of śrutaśravas ',
#  'somaka, an ancient king, son of sahadeva        ',
#  'somakīrti, a son of dhṛtarāṣṭra  ',
#  'stambamitra, a śārṅgaka, son of mandapala and jaritā ',
#  'sthūṇa2, a son of viśvāmitra',
#  'subāhu4, son of dhṛtarāṣṭra',
#  'subala4, a suparṇa, son of garuḍa ',
#  'sucāru1, son of kṛṣṇa and rakmiṇī ',
#  'sucāru2, son of dhṛtarāṣṭra ',
#  'sucetas, a brahman, son of gṛtsamada',
#  'sucitra3, son of dhṛtarāṣṭra ',
#  'suśruta, a son of viśvāmitra',
#  'sudarśa2, a son of dhṛtarāṣṭra  ',
#  'sudarśana7, son of dhṛtarāṣṭra   ',
#  'sudarśana1, son of agni and sudarcanā',
#  'sudyumna, an ancient king, son of manu vaivasvata   ',
#  'suhasta, son of dhṛtarāṣṭra    ',
#  'suhavis, son of bhumanyu ',
#  'suhotra1, an ancient king, son of bhumanyu   ',
#  'suhotra2, son of sahadeva pāṇḍava ',
#  'suhotṛ, son of bhumanyu ',
#  'sujāta, son of dhṛtarāṣṭra ',
#  ' lomaśa related when cyavana, the son of the maharṣi bhṛgu practised austerities by the side of this lake, and, assuming the posture vīrasthāna, had been enveloped by an anthill, king śaryāti came to the lake with his, wives and his only daughter sukanyā',
#  'suketu2, son of śiśupāla ',
#  'suketu3, son of citraketu ',
#  'sukṣatra, son of the kosala king ',
#  'sukuṇḍala, a son of dhṛtarāṣṭra ',
#  'sulocana1, a son of dhṛtarāṣṭra    ',
#  ' b  the bird s the son of suparṇa  beholding that all the birds on meru were of golden plumage, resolved to leave that mountain as there was no difference there between good, middling, and bad birds, ',
#  'sumukha4, son of dhṛtarāṣṭra ',
#  'sunābha1, a son of dhṛtarāṣṭra  ',
#  'sunāman1, son of suketu ',
#  'sunāman3, a suparṇa, son of garuḍa',
#  'sunetra2, a suparṇa, son of garuḍa ',
#  'sunītha5, son of kṛṣṇa and jāmbavatī  ',
#  'supārśva2, son of dhṛtarāṣṭra ',
#  'sūrakṛt, son of viśvāmitra',
#  'suratha6, a son of drupada ',
#  'suratha8, son of jayadratha ',
#  'suruc, a suparṇa, son of garuḍa ',
#  'sūryanetra, a suparṇa, son of garuḍa ',
#  'suṣeṇa2, a son of dhṛtarāṣṭra      ',
#  'suṣeṇa3, son of the elder parikṣit ',
#  'suṣeṇa5, son of jamadagni ',
#  'suṣeṇa8, son of karṇa  ',
#  'susvara, a suparṇa, son of garuḍa ',
#  'sūta3, son of viśvāmitra',
#  'sutasoma, son of bhīmasena  and draupadī             ',
#  'sūti, son of viśvāmitra',
#  'suvarcas1, son of dhṛtarāṣṭra',
#  'suvarcas4, a suparṇa, son of garuḍa ',
#  'suvarcas8 = karandhama, son of khanīnetra',
#  'suvarman1, son of dhṛtarāṣṭra    ',
#  'suvarṇābha, son of śaṅkhapada',
#  'suvarṇacūḍa, a suparṇa, son of garuḍa ',
#  'suvarṇaṣṭhīvin, son of sṛñjaya  ',
#  'suyajus, son of bhumanyu ',
#  'tāḍakāyana, a son of viśvāmitra',
#  'tejeyu, son of raudrāśva ',
#  ' there came to them balarāma, kṛṣṇa, śāmba, etc kārṣṇi, the grandson of śini, and other vṛṣṇis, and heard what had happened to them, and wept when they saw the pāṇḍavas so exceedingly lean ',
#  'triśiras = viśvarupa, the son of tvaṣṭṛ, ',
#  'trirāva, a suparṇa, son of garuḍa ',
#  'tuhuṇḍa2, a son of dhṛtarāṣṭra ',
#  'turvasu, son of yayāti and devayānī     ',
#  'tvaṣṭādhara, a son of śukra ',
#  'uccaiḥśravas2, son of avikṣit ',
#  'udāpekṣin, a son of viśvāmitra',
#  'ugra1, a son of dhṛtarāṣṭra    ',
#  'ugra3, a son of kavi',
#  'ugraśravas1, son of lomaharṣaṇa and generally named  sauti, who recited the mhbhr',
#  'ugraśravas2, a son of dhṛtarāṣṭra  ',
#  'ugrasena4, a son of dhṛtarāṣṭra  ',
#  'ugrasena5, son of the elder parikṣit ',
#  'ugrayāyin, a son of dhṛtarāṣṭra  ',
#  'ugrāyudha1, a son of dhṛtarāṣṭra    ',
#  'ujjayana, a son of viśvāmitra',
#  'ulūka1, kaitavya, son of śakuni             ',
#  'upacitra, a son of dhṛtarāṣṭra   ',
#  'upagahana, son of viśvāmitra',
#  'upananda2, a son of dhṛtarāṣṭra ',
#  'upanandaka1, a son of dhṛtarāṣṭra     ',
#  'ūrjayoni, a son of viśvāmitra',
#  'ūrṇanābha, a son of dhṛtarāṣṭra  ',
#  'utathya, a ṛṣi, son of aṅgiras   ',
#  'uttara1, son of virāṭa         ',
#  'vāhuli, a son of viśvāmitra',
#  'vainateya2, a suparṇa, son of garuḍa ',
#  'vairāṭa, a son of dhṛtarāṣṭra ',
#  'vajra1, son of viśvāmitra',
#  'vajraśīrṣa, a son of bhṛgu',
#  'vajradatta, king of prāgjyotiṣa, the son of bhagadatta ',
#  'vajraviṣkambha, a suparṇa, son of garuḍa ',
#  'vakṣogrīva, son of viśvāmitra',
#  'valgujaṅgha, a son of viśvāmitra',
#  'vālmīki2, a suparṇa, son of garuḍa ',
#  'vāmana3, a suparṇa, son of garuḍa ',
#  'vandi or vandin, a sūta, son of varuṇa  ',
#  'varcas1, son of soma',
#  'varcas3, son of sucetas',
#  'varcasvin1, son of varcas1 ',
#  ' do according to br  name of the sixth son of bhṛgu',
#  'variṣṭha2, son of manu cākṣuṣa ',
#  'vasāti1, son of the elder janamejaya ',
#  'vasiṣṭha, a ṛṣi, son of varuṇa, one of the saptarṣis, husband of arundhatī, father of śakti and grandfather of parāśara',
#  ' in kānyakubja king gādhi, son of kuśika, had a son viśvāmitra, who, with his ministers, used to go a hunting',
#  'vasu4, son of jamadagni ',
#  'vasudeva, son of śūra, husband of devakī, etc father of kṛṣṇa, etc     ',
#  'vasumanas1, an ancient king, son of haryaśva and mādhavī and grandson of yayāti      ',
#  'vasumat5, a king, son of janaka ',
#  'vātaghna, a son of viśvāmitra',
#  'vātavega1, son of dhṛtarāṣṭra   ʹ, ',
#  'vātavega2, a suparṇa, son of garuḍa ',
#  'vatsa1, a prince, son of the kāśi king pratardana',
#  'vāyubala, son of maṅkaṇaka',
#  'vāyucakra, son of maṅkaṇaka',
#  'vāyuhan, son of maṅkaṇaka',
#  'vāyujvāla, son of maṅkaṇaka',
#  'vāyumaṇḍala, son of maṅkaṇaka',
#  'vāyuretas, son of maṅkaṇaka',
#  'vāyuvega2, a son of dhṛtarāṣṭra ',
#  'vāyuvega3, son of maṅkaṇaka',
#  'vibhu1, a prince, son of the kāśi king      ',
#  'vibhu2, the sixth son of bhṛgu',
#  'vibhūti, son of viśvāmitra',
#  'vicitravīrya, a king, son of śāntanu and satyavatī                 ',
#  'viśālākṣa1, a son of dhṛtarāṣṭra   ',
#  'viśālākṣa3, a suparṇa, son of garuḍa ',
#  'viśvāmitra, a ṛṣi, son of gādhi bis ',
#  'viśvarūpa2, son of tvaṣṭṛ  ',
#  'viśvāvasu2, son of jamadagni ',
#  'vidūratha1, son of kuru and śubhāṅgī ',
#  'vijaya5, son of dhṛtarāṣṭra   ',
#  'vikarṇa1, a son of dhṛtarāṣṭra                                     ',
#  'vikata1, son of dhṛtarāṣṭra    ',
#  'vikaṭānana, son of dhṛtarāṣṭra ',
#  'viṃśa, son of ikṣvāku',
#  'vinda3, son of dhṛtarāṣṭra     ',
#  'vīra2, a son of dhṛtarāṣṭra ',
#  'vīrabāhu1, son of dhṛtarāṣṭra     ',
#  'virāja, son of avikṣit ',
#  'virajas2, son of dhṛtarāṣṭra  ',
#  'virajas3, a spiritual son of nārāyaṇa ',
#  'virajas4, son of kavi',
#  'virāvin, a son of dhṛtarāṣṭra  ',
#  'virocana2, a son of dhṛtarāṣṭra ',
#  'virūpa3, son of aṅgiras',
#  's incarnations are the following  a boar  yojanas in length  half lion, half man, when he killed the daitya king hiraṇyakaśipu, who attacked him with his śūla   the son of kaśyapa and aditi, in the form of a dwarf, born, years after the conception, of the hue of rain charged clouds and with bright eyes when he, accompanied by bṛhaspati, entered the sacrificial assembly of bali, the king of the dānavas, he, in three paces, took in the earth  and gave it to indra  kṛṣṇa, with conchshell, discus, and mace, aned with the śrīvatsa, clad in yellow silken robes, who protects arjuna, riding in the same chariot with him, ',
#  'viṣṇudharman, a suparṇa, son of garuḍa ',
#  'vitarka, son of the elder dhṛtarāṣṭra ',
#  'vitatya, a brahman, son of vihavya',
#  ' b, to dvitīyajanmany aṇḍasaṃjñitasya mārtaṇḍo ān śrāddhadevaḥ, son of aditi and born from an eggmārtaṇḍasya, father of the aśvins who came out of the nostrils of his wife sañjñā',
#  'viviṃśa1, son of dhṛtarāṣṭra ',
#  'viviṃśa2, a prince, son of viṃśa',
#  'viviṃśati, a son of dhṛtarāṣṭra                            ',
#  'vivitsu, a son of dhṛtarāṣṭra  ',
#  'vrajana, son of ajamīḍha ',
#  'vṛndāraka, a son of dhṛtarāṣṭra   ',
#  'vṛṣaka1, a gandhāra prince, son of subala, brother of acala and śakuni, and brother in law of dhṛtarāṣṭra, ',
#  'vṛṣasena3, son of karṇa     ʹ, ',
#  'vyāsa, a ṛṣi, the supposed compiler of mhbhr son of parāśara and satyavatī, father of śuka, and, with the wives of vicitravīrya, of dhṛtarāṣṭra, pāṇḍu, and vidura his proper name is kṛṣṇa, and on account of his being born on an island  he is called dvaipāyana  and kṛṣṇa dvaipāyana  he arranged the vedas, ',
#  'vyūḍhoraska, son of dhṛtarāṣṭra ',
#  'vyūḍhoru, son of dhṛtarāṣṭra  ',
#  'yaśodhara, son of kṛṣṇa and rukmiṇī ',
#  'yadu1, son of yayāti and ancestor of the yadus         ',
#  'yama1, lord of the spirits of the dead, son of vivasvat, often identified with dharma                                             ',
#  'yamadūta, a son of viśvāmitra',
#  ' dd in the y varuṇa, the son of aditi, had in days of yore, performed the rājasūya sacrifice having subjugated both men and celestials and g',
#  'yati1, son of nahuṣa ',
#  'yati2, a son of viśvāmitra',
#  'yaudheya, son of yudhiṣṭhira and devikā ',
#  'yauyudhāni, son of sātyaki ',
#  'yavakrīta, a ṛṣi, son of bharadvāja          ',
#  'yayāti, an ancient king, son of nahuṣa  bis   ',
#  'yudhiṣṭhira pāṇḍava, also named ajātaśatru and dharmarāja, eldest son of pāṇḍu and kuntī           ',
#  'yuyutsu, son of dhṛtarāṣṭra and a vaiśyā among eleven sons of dhṛtarāṣṭra who are mahārathasaṃśāvat']

# %%
from diaparser.parsers import Parser
parser = Parser.load('en_ewt.electra-base')

# %%
text = "Ariha3, seems to be a son of Dhrtarāṣṭras. "
dataset = parser.predict(text, text='en')
dataset.sentences[0]
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\torch\nn\modules\rnn.py:28: UserWarning: apply_permutation is deprecated, please use tensor.index_select(dim, permutation) instead
#   warnings.warn("apply_permutation is deprecated, please use tensor.index_select(dim, permutation) instead")
# # sent_id = 1
# # text = Ariha3, seems to be a son of Dhrtarāṣṭras.
# 1	Ariha3	_	_	_	_	3	nsubj	_	_
# 2	,	_	_	_	_	3	punct	_	_
# 3	seems	_	_	_	_	0	root	_	_
# 4	to	_	_	_	_	7	mark	_	_
# 5	be	_	_	_	_	7	cop	_	_
# 6	a	_	_	_	_	7	det	_	_
# 7	son	_	_	_	_	3	xcomp	_	_
# 8	of	_	_	_	_	9	case	_	_
# 9	Dhrtarāṣṭras	_	_	_	_	7	nmod	_	_
# 10	.	_	_	_	_	3	punct	_	_

# %%
text = "Āsurāyaṇi, a son of Viśvāmitra."
dataset = parser.predict(text, text='en')
dataset.sentences[0]
# Out:
# # sent_id = 1
# # text = Āsurāyaṇi, a son of Viśvāmitra.
# 1	Āsurāyaṇi	_	_	_	_	0	root	_	_
# 2	,	_	_	_	_	1	punct	_	_
# 3	a	_	_	_	_	4	det	_	_
# 4	son	_	_	_	_	1	appos	_	_
# 5	of	_	_	_	_	6	case	_	_
# 6	Viśvāmitra	_	_	_	_	4	nmod	_	_
# 7	.	_	_	_	_	4	punct	_	_

# %%
text = "Śaśija, son of the Moon = Budha."
dataset = parser.predict(text, text='en')
dataset.sentences[0]
# Out:
# # sent_id = 1
# # text = Śaśija, son of the Moon = Budha.
# 1	Śaśija	_	_	_	_	0	root	_	_
# 2	,	_	_	_	_	1	punct	_	_
# 3	son	_	_	_	_	1	appos	_	_
# 4	of	_	_	_	_	6	case	_	_
# 5	the	_	_	_	_	6	det	_	_
# 6	Moon	_	_	_	_	3	nmod	_	_
# 7	=	_	_	_	_	8	punct	_	_
# 8	Budha	_	_	_	_	1	parataxis	_	_
# 9	.	_	_	_	_	1	punct	_	_

# %%
text = "Jaritāri, the eldest son of Mandapāla and Jaritā"
dataset = parser.predict(text, text='en')
dataset.sentences[0]
# Out:
# # sent_id = 1
# # text = Jaritāri, the eldest son of Mandapāla and Jaritā
# 1	Jaritāri	_	_	_	_	0	root	_	_
# 2	,	_	_	_	_	1	punct	_	_
# 3	the	_	_	_	_	5	det	_	_
# 4	eldest	_	_	_	_	5	amod	_	_
# 5	son	_	_	_	_	1	appos	_	_
# 6	of	_	_	_	_	7	case	_	_
# 7	Mandapāla	_	_	_	_	5	nmod	_	_
# 8	and	_	_	_	_	9	cc	_	_
# 9	Jaritā	_	_	_	_	7	conj	_	_

# %%
text = "Khanīnetra, a king, son of Viviṃśa and father of Suvarcas"
dataset = parser.predict(text, text='en')
dataset.sentences[0]
# Out:
# # sent_id = 1
# # text = Khanīnetra, a king, son of Viviṃśa and father of Suvarcas
# 1	Khanīnetra	_	_	_	_	0	root	_	_
# 2	,	_	_	_	_	1	punct	_	_
# 3	a	_	_	_	_	4	det	_	_
# 4	king	_	_	_	_	1	appos	_	_
# 5	,	_	_	_	_	1	punct	_	_
# 6	son	_	_	_	_	1	appos	_	_
# 7	of	_	_	_	_	8	case	_	_
# 8	Viviṃśa	_	_	_	_	6	nmod	_	_
# 9	and	_	_	_	_	10	cc	_	_
# 10	father	_	_	_	_	6	conj	_	_
# 11	of	_	_	_	_	12	case	_	_
# 12	Suvarcas	_	_	_	_	10	nmod	_	_

# %%
text = "Pradyumna, son of Kṛṣṇa and Rukmiṇī."
dataset = parser.predict(text, text='en')
dataset.sentences[0]
# Out:
# # sent_id = 1
# # text = Pradyumna, son of Kṛṣṇa and Rukmiṇī.
# 1	Pradyumna	_	_	_	_	0	root	_	_
# 2	,	_	_	_	_	1	punct	_	_
# 3	son	_	_	_	_	1	appos	_	_
# 4	of	_	_	_	_	5	case	_	_
# 5	Kṛṣṇa	_	_	_	_	3	nmod	_	_
# 6	and	_	_	_	_	7	cc	_	_
# 7	Rukmiṇī	_	_	_	_	5	conj	_	_
# 8	.	_	_	_	_	1	punct	_	_

# %%
text = "citraketu, a suparna, son of garuda. "
dataset = parser.predict(text, text='en')
dataset.sentences[0]
# Out:
# # sent_id = 1
# # text = citraketu, a suparna, son of garuda.
# 1	citraketu	_	_	_	_	0	root	_	_
# 2	,	_	_	_	_	1	punct	_	_
# 3	a	_	_	_	_	4	det	_	_
# 4	suparna	_	_	_	_	1	appos	_	_
# 5	,	_	_	_	_	1	punct	_	_
# 6	son	_	_	_	_	1	appos	_	_
# 7	of	_	_	_	_	8	case	_	_
# 8	garuda	_	_	_	_	6	nmod	_	_
# 9	.	_	_	_	_	4	punct	_	_

# %%
extract_rel(['yaśodhara, son of kṛṣṇa and rukmiṇī'],'son')
# Out:
# [{'head': 'yashodhara',
#   'relation': 'son of',
#   'tail': 'krishna',
#   'text': 'yashodhara, son of krishna and rukmini.'},
#  {'head': 'yashodhara',
#   'relation': 'son of',
#   'tail': 'rukmini',
#   'text': 'yashodhara, son of krishna and rukmini.'}]

# %%
def extract_rel(sents,rel):
    ans_dict = []
    my_dict = {}
    found_relations=[]
    
    
    # sentences_10 = [ "He explained to him why kine have descended to earth In days of yore, when in the Deva yuga the Dānavas became lords of the three worlds, Aditi underwent the severest austerities and begot Viṣṇu seeing Aditi perform penances, Surabhī, the daughter of Dakṣa, also underwent austerities on Kailāsa, in yoga, standing upon one leg for, years Ṛ and M."]
    
    for sent in sents:
        if len(sent)<5:
            continue
        sent = remove_before_last_alphabet(sent)
        sent = transliterate_to_latin(sent)
        a = assign_token_ids((parser.predict(sent, text='en')).sentences[0])
        # finding head 
        head=""
        id=0
        for i in a:
    #         print(i)
            if i['word']==rel:
                id  = i['id']
                head_pointer = i['head']
                for j in a:
                    if j['id']==head_pointer:
                        head = j['word']
    
        if head=="":
            continue
            
        # finding tail 
        tails = []
        tail = ""
        for i in range(id+1 , len(a)):
            if a[i]['rel'] != 'nmod' or a[i]['word'] == 'king' or a[i]['word'] == 'queen':
                tail = tail + a[i]['word'] + " "
            else:
                tails.append(tail+a[i]['word'])
                j=i+1
                #find multiple tails if possible:
                while(j<len(a) and (a[j]['word'] in ['and',',','or'] or a[j]['rel'] == 'conj')):
                    if a[j]['word']=='and' or a[j]['word']==',' or a[j]['word']=='or':
                        del a[j]
                    elif a[j]['rel'] == 'conj':
                        tails.append(a[j]['word'])
                        j=j+1
                    
                break
    
        tails = [tail for tail in tails if len(tail.split()) < 6]

        
        for tail in tails:
            my_dict = {}
            my_dict['head']=head
            my_dict['relation']=rel+' of'
            my_dict['tail']=tail
            my_dict['text']=sent
            ans_dict.append(my_dict)
    
    return ans_dict

# %%
len(sents)
# Out:
# 728

# %%
rels = extract_rel(sents,"son")

# %%
rels
# Out:
# [{'head': 'varcas',
#   'relation': 'son of',
#   'tail': 'soma',
#   'text': 'abhimanyu, son of arjuna and subhadraa, sister of krishna, is an incarna tion of varcas, son of soma, wherefore he enters soma after death, after his karman has elapsed   etymology of his name  he is the vamshakara of the paandavas.'},
#  {'head': 'prince',
#   'relation': 'son of',
#   'tail': 'dushaasana',
#   'text': 'drona, etc abhimanyu  yudhishthira supporting jayadratha karna has one ear cut off abhimanyu slew vrindaaraka and brihadbala  abhimanyu once more pierced karna in the ear, and slew the son of the magadha king, and ashvaketu, and the bhoja prince of maarttikaavata  the son of dushaasana  abhimanyu ashvatthaaman   abhimanyu  shalya, who mounts another car abhimanyu slew shatrunjaya, etc.'},
#  {'head': 'raajarshi',
#   'relation': 'son of',
#   'tail': 'vashishtha',
#   'text': 'ashmaka1, a raajarshi, son of vashishtha and madayanti, the wife of kalmaashapaada.'},
#  {'head': 'raajarshi',
#   'relation': 'son of',
#   'tail': 'madayanti',
#   'text': 'ashmaka1, a raajarshi, son of vashishtha and madayanti, the wife of kalmaashapaada.'},
#  {'head': 'ashvalaayana',
#   'relation': 'son of',
#   'tail': 'vishvaamitras',
#   'text': 'ashvalaayana, a son of vishvaamitras.'},
#  {'head': 'ashvatthaaman1',
#   'relation': 'son of',
#   'tail': 'drona',
#   'text': 'ashvatthaaman1, son of drona and kripi.'},
#  {'head': 'ashvatthaaman1',
#   'relation': 'son of',
#   'tail': 'kripi',
#   'text': 'ashvatthaaman1, son of drona and kripi.'},
#  {'head': 'aadiraaja',
#   'relation': 'son of',
#   'tail': 'avikshit',
#   'text': 'aadiraaja, third son of avikshit and grandson of kuru.'},
#  {'head': 'aadiraaja',
#   'relation': 'son of',
#   'tail': 'grandson',
#   'text': 'aadiraaja, third son of avikshit and grandson of kuru.'},
#  {'head': 'adri1',
#   'relation': 'son of',
#   'tail': 'vishvagashva',
#   'text': 'adri1, son of vishvagashva, descendant of ikshvaaku.'},
#  {'head': 'adridha',
#   'relation': 'son of',
#   'tail': 'jaraasandha',
#   'text': 'adridha, son of jaraasandha.'},
#  {'head': 'brother',
#   'relation': 'son of',
#   'tail': 'mitra',
#   'text': 'agastya1, a rishi, brother of vasishtha and son of mitra and varuna he is called maitraavaruni  and kumbhayoni   he once saw his ancestors hanging in a cave, and was urged by them to procure progeny he then from the most beautiful parts of all animals created lopaamudraa and let her become the daughter of the king of vidarbha when he had married her he, in order to procure riches for her, applied successively to three kings, and then to the daanava ilvala, who shaped his own younger brother into a he goat that was digested by agastya.'},
#  {'head': 'brother',
#   'relation': 'son of',
#   'tail': 'varuna',
#   'text': 'agastya1, a rishi, brother of vasishtha and son of mitra and varuna he is called maitraavaruni  and kumbhayoni   he once saw his ancestors hanging in a cave, and was urged by them to procure progeny he then from the most beautiful parts of all animals created lopaamudraa and let her become the daughter of the king of vidarbha when he had married her he, in order to procure riches for her, applied successively to three kings, and then to the daanava ilvala, who shaped his own younger brother into a he goat that was digested by agastya.'},
#  {'head': 'ahamyaati',
#   'relation': 'son of',
#   'tail': 'samyaati',
#   'text': 'ahamyaati, a king, son of samyaati and father of saarvabhauma.'},
#  {'head': 'ahamyaati',
#   'relation': 'son of',
#   'tail': 'father',
#   'text': 'ahamyaati, a king, son of samyaati and father of saarvabhauma.'},
#  {'head': 'aja6',
#   'relation': 'son of',
#   'tail': 'jahnu',
#   'text': 'aja6, son of jahnu.'},
#  {'head': 'raajarshi',
#   'relation': 'son of',
#   'tail': 'aayu',
#   'text': 'the serpent said that he was the raajarshi nahusha, the son of aayu, whom agastya had cursed to become a serpent, out of compassion, however, adding to his curse that the person who would be able to answer his questions would deliver him, and that even stronger beings would, when seized by him, lose their strength.'},
#  {'head': 'akshina',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'akshina, son of vishvaamitra.'},
#  {'head': 'alolupa',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'alolupa, son of dhritaraashtra.'},
#  {'head': 'amatsyaashin',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'amatsyaashin, son of vishvaamitra.'},
#  {'head': 'amaavasu',
#   'relation': 'son of',
#   'tail': 'pururavas',
#   'text': 'amaavasu, son of pururavas and urvashi.'},
#  {'head': 'amaavasu',
#   'relation': 'son of',
#   'tail': 'urvashi',
#   'text': 'amaavasu, son of pururavas and urvashi.'},
#  {'head': 'ambhoruha',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'ambhoruha, son of vishvaamitra.'},
#  {'head': 'shukra',
#   'relation': 'son of',
#   'tail': 'a rishi',
#   'text': 'the upaadhyaaya of the asuras was shukra or ushanas, son of a rishi he had four sons who sacrificed for the asuras  they were brahmaloka paraayanaa.'},
#  {'head': 'amshumat2',
#   'relation': 'son of',
#   'tail': 'king sagara',
#   'text': 'amshumat2, the sons son of king sagara.'},
#  {'head': 'anaadhrishti3',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'anaadhrishti3, son of dhritaraashtra.'},
#  {'head': 'anaadhrishya',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'anaadhrishya, a son of dhritaraashtra.'},
#  {'head': 'suparna',
#   'relation': 'son of',
#   'tail': 'garuda',
#   'text': 'anagha6, a suparna, son of garuda.'},
#  {'head': 'anala1',
#   'relation': 'son of',
#   'tail': 'prajaapati',
#   'text': 'anala1, one of the eight vasus, son of prajaapati  or dharma  and shaandili, and father of skanda.'},
#  {'head': 'anala1',
#   'relation': 'son of',
#   'tail': 'dharma',
#   'text': 'anala1, one of the eight vasus, son of prajaapati  or dharma  and shaandili, and father of skanda.'},
#  {'head': 'anala1',
#   'relation': 'son of',
#   'tail': 'shaandili',
#   'text': 'anala1, one of the eight vasus, son of prajaapati  or dharma  and shaandili, and father of skanda.'},
#  {'head': 'anala1',
#   'relation': 'son of',
#   'tail': 'father',
#   'text': 'anala1, one of the eight vasus, son of prajaapati  or dharma  and shaandili, and father of skanda.'},
#  {'head': 'anala2',
#   'relation': 'son of',
#   'tail': 'garuda',
#   'text': 'anala2, a suparna, son of garuda.'},
#  {'head': 'ananga1',
#   'relation': 'son of',
#   'tail': 'kardama',
#   'text': 'ananga1, son of kardama.'},
#  {'head': 'anenas',
#   'relation': 'son of',
#   'tail': 'aayus',
#   'text': 'anenas, son of aayus and svarbhaanavi.'},
#  {'head': 'anenas',
#   'relation': 'son of',
#   'tail': 'svarbhaanavi',
#   'text': 'anenas, son of aayus and svarbhaanavi.'},
#  {'head': 'angada1',
#   'relation': 'son of',
#   'tail': 'vaalin',
#   'text': 'angada1, a monkey chief, son of vaalin.'},
#  {'head': 'angada2',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'angada2, son of dhritaraashtra.'},
#  {'head': 'anghrika',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'anghrika, son of vishvaamitra.'},
#  {'head': 'knowing',
#   'relation': 'son of',
#   'tail': 'fire',
#   'text': 'angiras also had a son, brihaspati knowing him the aangirasa to be the firstborn son of fire, the gods came and learned the matter from angiras.'},
#  {'head': 'suparna',
#   'relation': 'son of',
#   'tail': 'garuda',
#   'text': 'anila3, a suparna, son of garuda.'},
#  {'head': 'antevasaayin',
#   'relation': 'son of',
#   'tail': 'a nishaadi',
#   'text': 'antevasaayin, son of a nishaadi and a caandaala.'},
#  {'head': 'anu',
#   'relation': 'son of',
#   'tail': 'yayaati',
#   'text': 'anu, son of yayaati.'},
#  {'head': 'anudara',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'anudara, son of dhritaraashtra.'},
#  {'head': 'child',
#   'relation': 'son of',
#   'tail': 'maadri',
#   'text': 'o sahadeva cease to go thou art my dearest child, o son of maadri the paandavas, having consoled her, set out for the woods, and vidura led her to his house.'},
#  {'head': 'krisharas',
#   'relation': 'son of',
#   'tail': 'jayadrathaorphanorphan',
#   'text': 'dhaumya, nil descriptionwith krisharas, and meat, and nivaapas mixed with sesame seeds descriptionfour miles, pcr description with articles destructive of raa tena satyena, page0 b  etymologydescription, with the permission of dhritaraashtra, description, the sons and grandsons of the slain, description, jepu, page0 a the son of jayadrathaorphanorphan, step description of his car, touching water, approved by gangaawhile he was engaged with shikhandin and had ceased to fightdvijaatipariveshakapage0 b, b.'},
#  {'head': 'anuhlaada',
#   'relation': 'son of',
#   'tail': 'hiranyakashipu',
#   'text': 'anuhlaada, son of hiranyakashipu.'},
#  {'head': 'janamejaya',
#   'relation': 'son of',
#   'tail': 'parikshit',
#   'text': 'the suta ugrashravas, son of lomaharshana, had heard the mahaabhaarata, which had been composed by vyaasa, recited under the direction of dvai paayana  himself by vaishampaayana, disciple of vyaasa, at the serpent sacrifice of king janamejaya, son of parikshit he had thereupon undertaken a pilgrimage to the tirthas  and visited samantapancaka  thence he came to the twelve years sattra  of  shaunaka in the naimisha forest, where he related the mahaabhaarata, beginning with the aation of vishnu identified with the absolute, and  a brief exposition of the creation and succession of beings from the absolute through brahmaan, the prajaapatis, gods, etc n to the families of the kurus, etc mentioned in the poem.'},
#  {'head': 'anuvinda3',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'anuvinda3, son of dhritaraashtra.'},
#  {'head': 'anuyaayin',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'anuyaayin, a son of dhritaraashtra.'},
#  {'head': 'apaantaratama',
#   'relation': 'son of',
#   'tail': 'sarasvati',
#   'text': 'apaantaratama, son of sarasvati.'},
#  {'head': 'aparaajita3',
#   'relation': 'son of',
#   'tail': 'dhritaraashtras',
#   'text': 'aparaajita3, a son of dhritaraashtras.'},
#  {'head': 'vasishtha',
#   'relation': 'son of',
#   'tail': 'varuna',
#   'text': 'gangaa fully related to shaantanu the reason why the brahmarshi vasishtha, the son of varuna, had cursed the vasus.'},
#  {'head': 'araani',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'araani, a son of vishvaamitra.'},
#  {'head': 'ariha1',
#   'relation': 'son of',
#   'tail': 'avaacina',
#   'text': 'ariha1, son of avaacina.'},
#  {'head': 'ariha2',
#   'relation': 'son of',
#   'tail': 'devaatithi',
#   'text': 'ariha2, son of devaatithi.'},
#  {'head': 'seems',
#   'relation': 'son of',
#   'tail': 'dhrtaraashtras',
#   'text': 'ariha3, seems to be a son of dhrtaraashtras.'},
#  {'head': 'asa',
#   'relation': 'son of',
#   'tail': 'sagara',
#   'text': 'asamanjas1, at the request of yudhishthira, lomasha related asa manjas, the son of sagara and shaibyaa, used to seize the children of the citizens by the throat and throw them into the river.'},
#  {'head': 'asa',
#   'relation': 'son of',
#   'tail': 'shaibyaa',
#   'text': 'asamanjas1, at the request of yudhishthira, lomasha related asa manjas, the son of sagara and shaibyaa, used to seize the children of the citizens by the throat and throw them into the river.'},
#  {'head': 'shvetaketu',
#   'relation': 'son of',
#   'tail': 'uddaalaka',
#   'text': 'uddaalaka prevailed upon sujaataa to keep it a secret from ashtaavakra, who regarded uddaalaka as his father and shvetaketu, the son of uddaalaka, who was of the same age with himself, as his brother, until in his th year shvetaketu in anger happened to disclose the matter to him.'},
#  {'head': 'king',
#   'relation': 'son of',
#   'tail': 'abhimanyu',
#   'text': 'king parikshit, the son of abhimanyu, was cursed and consequently struck to death by takshaka kaashyapa was bribed to return without curing him.'},
#  {'head': 'aasuraayani',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'aasuraayani, a son of vishvaamitra.'},
#  {'head': 'aurva',
#   'relation': 'son of',
#   'tail': 'cyavana',
#   'text': 'aurva   son of cyavana and aarushi and father of ricika.'},
#  {'head': 'aurva',
#   'relation': 'son of',
#   'tail': 'aarushi',
#   'text': 'aurva   son of cyavana and aarushi and father of ricika.'},
#  {'head': 'aurva',
#   'relation': 'son of',
#   'tail': 'father',
#   'text': 'aurva   son of cyavana and aarushi and father of ricika.'},
#  {'head': 'kaarandhama',
#   'relation': 'son of',
#   'tail': 'suvarcas',
#   'text': 'kaarandhama, son of suvarcas, lived at the beginning of the tretaa age, and was equal to indra, brihaspati, and himavat all kings were under his control he was given to sacrifices, he performed hundreds of horse sacriflces, and angiras himself served as his priest.'},
#  {'head': 'janamejaya',
#   'relation': 'son of',
#   'tail': 'parikshit',
#   'text': 'about the time of king janamejaya, son of parikshit, there was a rishi named aa.'},
#  {'head': 'bhima1',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'bhima1, son of dhritaraashtra.'},
#  {'head': 'bhimabala2',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'bhimabala2, a son of dhritaraashtra.'},
#  {'head': 'bhimashara',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'bhimashara, a son of dhritaraashtra.'},
#  {'head': 'bhimaratha1',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'bhimaratha1, a son of dhritaraashtra.'},
#  {'head': 'bhimavega',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'bhimavega, son of dhritaraashtra.'},
#  {'head': 'bhishma',
#   'relation': 'son of',
#   'tail': 'shaantanu',
#   'text': 'bhishma      in like manner bhishma, the son of shaantanu, was born in the womb of gangaa from the seed of the vasus.'},
#  {'head': 'took',
#   'relation': 'son of',
#   'tail': 'shini',
#   'text': 'when, however, the kalingas were rallied again, dhrishtadyumna, with shikhandin, yudhi shthira, etc protected one of the wings of bhimasena there was nobody on earth, save bhima and saatyaki, who was dearer to dhrishtadyumna than his very life they beheld saatyaki at a distance and that son of shini took up the wing of both bhima and dhrishtadyumna bhima caused a bloody river to flow there.'},
#  {'head': 'took',
#   'relation': 'son of',
#   'tail': 'took',
#   'text': 'when, however, the kalingas were rallied again, dhrishtadyumna, with shikhandin, yudhi shthira, etc protected one of the wings of bhimasena there was nobody on earth, save bhima and saatyaki, who was dearer to dhrishtadyumna than his very life they beheld saatyaki at a distance and that son of shini took up the wing of both bhima and dhrishtadyumna bhima caused a bloody river to flow there.'},
#  {'head': 'given',
#   'relation': 'son of',
#   'tail': 'his',
#   'text': 'while they, in days of old, practised penances, preparing themselves for  brahmaloka by yoga meditation, there occurred a severe drought shibis son shaibya had in former times given away a son of his as the sacrificial present to the ritvijes that prince now died of starvation impelled by hunger, the rishis cooked his body in a vessel.'},
#  {'head': 'brihadbala2',
#   'relation': 'son of',
#   'tail': 'subala',
#   'text': 'brihadbala2, son of subala, the gaandhaara king.'},
#  {'head': 'brihadgarbha',
#   'relation': 'son of',
#   'tail': 'shibi',
#   'text': 'brihadgarbha, son of shibi aushinara.'},
#  {'head': 'brihatkirti',
#   'relation': 'son of',
#   'tail': 'angiras',
#   'text': 'brihatkirti, son of angiras.'},
#  {'head': 'cakraka',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'cakraka, son of vishvaamitra.'},
#  {'head': 'caampeya',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'caampeya, son of vishvaamitra.'},
#  {'head': 'candakaushika',
#   'relation': 'son of',
#   'tail': 'kaakshivat',
#   'text': 'candakaushika, a muni, son of kaakshivat.'},
#  {'head': 'candatundaka',
#   'relation': 'son of',
#   'tail': 'garuda',
#   'text': 'candatundaka, a suparna, son of garuda.'},
#  {'head': 'candraashva',
#   'relation': 'son of',
#   'tail': 'kuvalaashva',
#   'text': 'candraashva, son of kuvalaashva.'},
#  {'head': 'candrasena1',
#   'relation': 'son of',
#   'tail': 'samudrasena',
#   'text': 'candrasena1, a prince, son of samudrasena.'},
#  {'head': 'caarucitra',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'caarucitra, son of dhritaraashtra.'},
#  {'head': 'caarucitraangada',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'caarucitraangada, son of dhritaraashtra.'},
#  {'head': 'caarushravas',
#   'relation': 'son of',
#   'tail': 'krishna',
#   'text': 'caarushravas, son of krishna and rukmini.'},
#  {'head': 'caarushravas',
#   'relation': 'son of',
#   'tail': 'rukmini',
#   'text': 'caarushravas, son of krishna and rukmini.'},
#  {'head': 'caarudeshna',
#   'relation': 'son of',
#   'tail': 'krishna',
#   'text': 'caarudeshna, son of krishna and rukmini.'},
#  {'head': 'caarudeshna',
#   'relation': 'son of',
#   'tail': 'rukmini',
#   'text': 'caarudeshna, son of krishna and rukmini.'},
#  {'head': 'caaruvesha',
#   'relation': 'son of',
#   'tail': 'krishna',
#   'text': 'caaruvesha, son of krishna and rukmini.'},
#  {'head': 'caaruvesha',
#   'relation': 'son of',
#   'tail': 'rukmini',
#   'text': 'caaruvesha, son of krishna and rukmini.'},
#  {'head': 'caaruyashas',
#   'relation': 'son of',
#   'tail': 'krishna',
#   'text': 'caaruyashas, son of krishna and rukmini.'},
#  {'head': 'caaruyashas',
#   'relation': 'son of',
#   'tail': 'rukmini',
#   'text': 'caaruyashas, son of krishna and rukmini.'},
#  {'head': 'cirakaari',
#   'relation': 'son of',
#   'tail': 'gautama',
#   'text': 'cirakaari, cirakaarika, cirakaarin, son of gautama.'},
#  {'head': 'ciraantaka',
#   'relation': 'son of',
#   'tail': 'garuda',
#   'text': 'ciraantaka, a suparna, son of garuda.'},
#  {'head': 'citra1',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'citra1, son of dhritaraashtra.'},
#  {'head': 'citrabaahu',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'citrabaahu, son of dhritaraashtra.'},
#  {'head': 'citrabarha',
#   'relation': 'son of',
#   'tail': 'garuda',
#   'text': 'citrabarha, a suparna, son of garuda.'},
#  {'head': 'citrabarhin',
#   'relation': 'son of',
#   'tail': 'garuda',
#   'text': 'citrabarhin, son of garuda.'},
#  {'head': 'citracaapa',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'citracaapa, son of dhritaraashtra.'},
#  {'head': 'citraka1',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'citraka1, son of dhritaraashtra.'},
#  {'head': 'suparna',
#   'relation': 'son of',
#   'tail': 'garuda',
#   'text': 'citraketu1, a suparna, son of garuda.'},
#  {'head': 'citraaksha',
#   'relation': 'son of',
#   'tail': 'dhritarashtra',
#   'text': 'citraaksha, son of dhritarashtra.'},
#  {'head': 'citrakundala',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'citrakundala, son of dhritaraashtra.'},
#  {'head': 'citraanga',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'citraanga, son of dhritaraashtra.'},
#  {'head': 'citraangada1',
#   'relation': 'son of',
#   'tail': 'shaantanu',
#   'text': 'citraangada1, son of shaantanu and satyavati.'},
#  {'head': 'citraangada1',
#   'relation': 'son of',
#   'tail': 'satyavati',
#   'text': 'citraangada1, son of shaantanu and satyavati.'},
#  {'head': 'citraangadaasuta',
#   'relation': 'son of',
#   'tail': 'citraangadaa',
#   'text': 'citraangadaasuta, son of citraangadaa = babhruvaahana.'},
#  {'head': 'citrasena1',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'citrasena1, son of dhritaraashtra.'},
#  {'head': 'citrasena2',
#   'relation': 'son of',
#   'tail': 'the elder parikshit',
#   'text': 'citrasena2, son of the elder parikshit.'},
#  {'head': 'citrasena1',
#   'relation': 'son of',
#   'tail': 'karna',
#   'text': 'citrasena1, son of karna.'},
#  {'head': 'citravaana',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'citravaana, son of dhritaraashtra.'},
#  {'head': 'citravarman1',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'citravarman1, son of dhritaraashtra.'},
#  {'head': 'citravarman4',
#   'relation': 'son of',
#   'tail': 'sucitra',
#   'text': 'citravarman4, son of sucitra.'},
#  {'head': 'citraayudha1',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'citraayudha1, son of dhritaraashtra.'},
#  {'head': 'rishi',
#   'relation': 'son of',
#   'tail': 'bhrigu',
#   'text': 'cyavana1, a rishi, son of bhrigu.'},
#  {'head': 'king',
#   'relation': 'son of',
#   'tail': 'citraratha bis king sh',
#   'text': 'shashabindu1, an ancient king, son of citraratha bis    king sh.'},
#  {'head': 'shashija',
#   'relation': 'son of',
#   'tail': 'the moon',
#   'text': 'shashija, son of the moon = budha.'},
#  {'head': 'son',
#   'relation': 'son of',
#   'tail': 'indra',
#   'text': 'shakraatmajaatmaja, son of the son of indra = abhi manyu.'},
#  {'head': 'shaaktra',
#   'relation': 'son of',
#   'tail': 'shakti',
#   'text': 'shaaktra, son of shakti = paraashara.'},
#  {'head': 'shaktri',
#   'relation': 'son of',
#   'tail': 'vasishtha',
#   'text': 'shaktri, a rishi, son of vasishtha and father of paraashara.'},
#  {'head': 'shaktri',
#   'relation': 'son of',
#   'tail': 'father',
#   'text': 'shaktri, a rishi, son of vasishtha and father of paraashara.'},
#  {'head': 'shaktrija',
#   'relation': 'son of',
#   'tail': 'shakti',
#   'text': 'shaktrija, son of shakti = paraashara.'},
#  {'head': 'shakuniputra',
#   'relation': 'son of',
#   'tail': 'shakuni',
#   'text': 'shakuniputra, the son of shakuni, king of the gaandhaaras.'},
#  {'head': 'shakunta',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'shakunta, son of vishvaamitra.'},
#  {'head': 'shaakuntala',
#   'relation': 'son of',
#   'tail': 'shakuntalaa',
#   'text': 'shaakuntala, son of shakuntalaa  = bharata.'},
#  {'head': 'shala2',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'shala2, son of dhritaraashtra.'},
#  {'head': 'shala3',
#   'relation': 'son of',
#   'tail': 'somadatta',
#   'text': 'shala3, son of somadatta and brother of bhuri and bhurishravas.'},
#  {'head': 'shala3',
#   'relation': 'son of',
#   'tail': 'brother',
#   'text': 'shala3, son of somadatta and brother of bhuri and bhurishravas.'},
#  {'head': 'shala4',
#   'relation': 'son of',
#   'tail': 'king parikshit',
#   'text': 'shala4, son of king parikshit of ayodhyaa and the daughter of the frog king.'},
#  {'head': 'shaalmali1',
#   'relation': 'son of',
#   'tail': 'avikshit',
#   'text': 'shaalmali1, son of avikshit.'},
#  {'head': 'shaamba1',
#   'relation': 'son of',
#   'tail': 'krishna',
#   'text': 'shaamba1, son of krishna and jaambavati.'},
#  {'head': 'shaamba1',
#   'relation': 'son of',
#   'tail': 'jaambavati',
#   'text': 'shaamba1, son of krishna and jaambavati.'},
#  {'head': 'shambhu7',
#   'relation': 'son of',
#   'tail': 'krishna',
#   'text': 'shambhu7, son of krishna and rukmini.'},
#  {'head': 'shambhu7',
#   'relation': 'son of',
#   'tail': 'rukmini',
#   'text': 'shambhu7, son of krishna and rukmini.'},
#  {'head': 'shanaishcara1',
#   'relation': 'son of',
#   'tail': 'surya',
#   'text': 'shanaishcara1, the planet saturn, son of surya.'},
#  {'head': 'shankhapada',
#   'relation': 'son of',
#   'tail': 'manu',
#   'text': 'shankhapada, son of manu svaarocisha.'},
#  {'head': 'shankukarna2',
#   'relation': 'son of',
#   'tail': 'janamejaya',
#   'text': 'shankukarna2, son of janamejaya.'},
#  {'head': 'shaanta1',
#   'relation': 'son of',
#   'tail': 'the vasu ahas',
#   'text': 'shaanta1, son of the vasu ahas.'},
#  {'head': 'shaantanu',
#   'relation': 'son of',
#   'tail': 'pratipa',
#   'text': 'shaantanu, son of pratipa and father of bhishma, citraangada, and vicitravirya.'},
#  {'head': 'shaantanu',
#   'relation': 'son of',
#   'tail': 'father',
#   'text': 'shaantanu, son of pratipa and father of bhishma, citraangada, and vicitravirya.'},
#  {'head': 'shaanti3',
#   'relation': 'son of',
#   'tail': 'angiras',
#   'text': 'shaanti3, son of angiras.'},
#  {'head': 'sharabha5',
#   'relation': 'son of',
#   'tail': 'shishupaala',
#   'text': 'sharabha5, son of shishupaala.'},
#  {'head': 'sharaasana',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'sharaasana, son of dhritaraashtra.'},
#  {'head': 'sharyaati',
#   'relation': 'son of',
#   'tail': 'manu',
#   'text': 'sharyaati, an ancient king, son of manu vaivasvata.'},
#  {'head': 'shataanika1',
#   'relation': 'son of',
#   'tail': 'nakula',
#   'text': 'shataanika1, son of nakula paandava and draupadi.'},
#  {'head': 'shataayus1',
#   'relation': 'son of',
#   'tail': 'pururavas',
#   'text': 'shataayus1, son of pururavas.'},
#  {'head': 'shatrughna1',
#   'relation': 'son of',
#   'tail': 'dasharatha',
#   'text': 'shatrughna1, son of dasharatha.'},
#  {'head': 'shatrunjaya2',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'shatrunjaya2, son of dhritaraashtra.'},
#  {'head': 'shatrunjaya5',
#   'relation': 'son of',
#   'tail': 'drupada',
#   'text': 'shatrunjaya5, son of drupada.'},
#  {'head': 'shatrusaha',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'shatrusaha, son of dhritaraashtra.'},
#  {'head': 'shauri1',
#   'relation': 'son of',
#   'tail': 'shura',
#   'text': 'shauri1, son of shura = vasudeva.'},
#  {'head': 'king',
#   'relation': 'son of',
#   'tail': 'ushinara',
#   'text': 'shibi1, a king, son of ushinara.'},
#  {'head': 'shishupaala',
#   'relation': 'son of',
#   'tail': 'damaghosha',
#   'text': 'shishupaala, king of the cedis, son of damaghosha.'},
#  {'head': 'installed',
#   'relation': 'son of',
#   'tail': 'shishupaala',
#   'text': 'yudhishthira caused his brothers to perform the funeral rites of shishupaala, the son of damaghosha then he, with all the kings, installed the son of shishupaala in the sovereignty of the cedis v.'},
#  {'head': 'shilaayupa',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'shilaayupa, a son of vishvaamitra.'},
#  {'head': 'shirshin',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'shirshin, a son of vishvaamitra.'},
#  {'head': 'shita',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'shita, a son of vishvaamitra.'},
#  {'head': 'skanda',
#   'relation': 'son of',
#   'tail': 'agnirudrena',
#   'text': 'skanda, the son of agnirudrena shukram utsrishtam tac chveta parvato bhavatanupravishya rudrena vahnim jaato hy ayam shishu, i.'},
#  {'head': 'shrimat1',
#   'relation': 'son of',
#   'tail': 'nimi',
#   'text': 'shrimat1, son of nimi.'},
#  {'head': 'shrutakarman1',
#   'relation': 'son of',
#   'tail': 'sahadeva',
#   'text': 'shrutakarman1, son of sahadeva and draupadi.'},
#  {'head': 'shrutakarman1',
#   'relation': 'son of',
#   'tail': 'draupadi',
#   'text': 'shrutakarman1, son of sahadeva and draupadi.'},
#  {'head': 'shrutakarman2',
#   'relation': 'son of',
#   'tail': 'arjuna',
#   'text': 'shrutakarman2, son of arjuna and draupadi.'},
#  {'head': 'shrutakarman2',
#   'relation': 'son of',
#   'tail': 'draupadi',
#   'text': 'shrutakarman2, son of arjuna and draupadi.'},
#  {'head': 'shrutakarman3',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'shrutakarman3, son of dhritaraashtra.'},
#  {'head': 'shrutaanta',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'shrutaanta, son of dhritaraashtra.'},
#  {'head': 'shrutarvan2',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'shrutarvan2, son of dhritaraashtra.'},
#  {'head': 'shrutasena3',
#   'relation': 'son of',
#   'tail': 'sahadeva',
#   'text': 'shrutasena3, son of sahadeva and draupadi.'},
#  {'head': 'shrutasena3',
#   'relation': 'son of',
#   'tail': 'draupadi',
#   'text': 'shrutasena3, son of sahadeva and draupadi.'},
#  {'head': 'shringin1',
#   'relation': 'son of',
#   'tail': 'shamika',
#   'text': 'shringin1, son of shamika.'},
#  {'head': 'shuci8',
#   'relation': 'son of',
#   'tail': 'vicvaamitra',
#   'text': 'shuci8, a son of vicvaamitra.'},
#  {'head': 'shuci1',
#   'relation': 'son of',
#   'tail': 'bhrigu',
#   'text': 'shuci1, a son of bhrigu.'},
#  {'head': 'shuka1',
#   'relation': 'son of',
#   'tail': 'vyaasa',
#   'text': 'shuka1, son of vyaasa.'},
#  {'head': 'warrior',
#   'relation': 'son of',
#   'tail': 'subala',
#   'text': 'shuka4, a gandhaara warrior, the son of subala.'},
#  {'head': 'shunashepha',
#   'relation': 'son of',
#   'tail': 'ricika',
#   'text': 'shunashepha, son of ricika.'},
#  {'head': 'shura3',
#   'relation': 'son of',
#   'tail': 'ilina',
#   'text': 'shura3, son of ilina.'},
#  {'head': 'muni',
#   'relation': 'son of',
#   'tail': 'uddaalaka',
#   'text': 'shvetaketu1, a muni, son of uddaalaka.'},
#  {'head': 'shyaamaayana',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'shyaamaayana, son of vishvaamitra.'},
#  {'head': 'shyenajit1',
#   'relation': 'son of',
#   'tail': 'dala',
#   'text': 'shyenajit1, son of dala.'},
#  {'head': 'dashajyotis',
#   'relation': 'son of',
#   'tail': 'subhraaj',
#   'text': 'dashajyotis, son of subhraaj.'},
#  {'head': 'daityadvipa',
#   'relation': 'son of',
#   'tail': 'garuda',
#   'text': 'daityadvipa, a suparna, son of garuda.'},
#  {'head': 'suparna',
#   'relation': 'son of',
#   'tail': 'garuda',
#   'text': 'daksha2, a suparna, son of garuda.'},
#  {'head': 'dala',
#   'relation': 'son of',
#   'tail': 'king parikshit',
#   'text': 'dala, son of king parikshit of ayodhyaa, and sushobhanaa the daughter of the frog king.'},
#  {'head': 'dama1',
#   'relation': 'son of',
#   'tail': 'bhima',
#   'text': 'dama1, son of bhima, the vidarbha king.'},
#  {'head': 'dandin1',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'dandin1, son of dhritaraashtra.'},
#  {'head': 'darpa',
#   'relation': 'son of',
#   'tail': 'adharma',
#   'text': 'darpa, son of adharma and shri.'},
#  {'head': 'darpa',
#   'relation': 'son of',
#   'tail': 'shri',
#   'text': 'darpa, son of adharma and shri.'},
#  {'head': 'suparna',
#   'relation': 'son of',
#   'tail': 'garuda',
#   'text': 'daaruna1, a suparna, son of garuda.'},
#  {'head': 'daushaasani',
#   'relation': 'son of',
#   'tail': 'dushaasana',
#   'text': 'daushaasani, patron the son of dushaasana dhaartaraashtra.'},
#  {'head': 'devaapi',
#   'relation': 'son of',
#   'tail': 'pratipa',
#   'text': 'devaapi, son of pratipa.'},
#  {'head': 'muni',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'devaraata2, a muni, son of vishvaamitra.'},
#  {'head': 'succeed',
#   'relation': 'son of',
#   'tail': 'yayaati',
#   'text': 'ushanas cursed yayaati to be overcome by decrepitude, yet with the permission of trans ferring it to someone else, and he added that that son of yayaati who would give him his own youth should succeed yayaati on the throne, etc.'},
#  {'head': 'dhanurdhara1',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'dhanurdhara1, a son of dhritaraashtra.'},
#  {'head': 'dhanurgraha',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'dhanurgraha, a son of dhritaraashtra  ʹ.'},
#  {'head': 'dhanurgraaha',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'dhanurgraaha, a son of dhritaraashtra.'},
#  {'head': 'examined',
#   'relation': 'son of',
#   'tail': 'krishna',
#   'text': 'examined janakauttankathe eldest son of krishna nakulaakhyanain the shape of a brahman dh.'},
#  {'head': 'dhruva2',
#   'relation': 'son of',
#   'tail': 'nahusha',
#   'text': 'dhruva2, son of nahusha.'},
#  {'head': 'dhrishnu1',
#   'relation': 'son of',
#   'tail': 'manu',
#   'text': 'dhrishnu1, son of manu vaivasvata.'},
#  {'head': 'dhrishnu2',
#   'relation': 'son of',
#   'tail': 'kavi',
#   'text': 'dhrishnu2, son of kavi.'},
#  {'head': 'dhrishtaketu2',
#   'relation': 'son of',
#   'tail': 'shishupaala',
#   'text': 'dhrishtaketu2, king of the cedis, son of shishupaala.'},
#  {'head': 'dhritaraashtra1',
#   'relation': 'son of',
#   'tail': 'vyaasa',
#   'text': 'dhritaraashtra1, son of vyaasa with ambikaa, the wi of vicitravirya.'},
#  {'head': 'king',
#   'relation': 'son of',
#   'tail': 'the elder janamejaya',
#   'text': 'dhritaraashtra4, a king, son of the elder janamejaya.'},
#  {'head': 'asura',
#   'relation': 'son of',
#   'tail': 'madhu',
#   'text': 'dhundhu1, an asura, son of madhu and kaitabha.'},
#  {'head': 'asura',
#   'relation': 'son of',
#   'tail': 'kaitabha',
#   'text': 'dhundhu1, an asura, son of madhu and kaitabha.'},
#  {'head': 'dishaacakshu',
#   'relation': 'son of',
#   'tail': 'garuda',
#   'text': 'dishaacakshu, a suparna, the son of garuda.'},
#  {'head': 'dipaka',
#   'relation': 'son of',
#   'tail': 'garuda',
#   'text': 'dipaka, a suparna, the son of garuda.'},
#  {'head': 'dirghabaahu',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'dirghabaahu, son of dhritaraashtra.'},
#  {'head': 'dirghajihva',
#   'relation': 'son of',
#   'tail': 'danu',
#   'text': 'dirghajihva, an asura, son of danu.'},
#  {'head': 'dirghalocana',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'dirghalocana, son of dhritaraashtra.'},
#  {'head': 'dirgharoma',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'dirgharoma, son of dhritaraashtra.'},
#  {'head': 'dirghaayus',
#   'relation': 'son of',
#   'tail': 'ashyutaayus',
#   'text': 'dirghaayus, son of ashyutaayus.'},
#  {'head': 'suparna',
#   'relation': 'son of',
#   'tail': 'garuda',
#   'text': 'divaakara1, a suparna, the son of garuda.'},
#  {'head': 'diviratha1',
#   'relation': 'son of',
#   'tail': 'bhumanyu',
#   'text': 'diviratha1, the son of bhumanyu.'},
#  {'head': 'diviratha2',
#   'relation': 'son of',
#   'tail': 'dadhivaahana',
#   'text': 'diviratha2, the son of dadhivaahana.'},
#  {'head': 'divodaasa',
#   'relation': 'son of',
#   'tail': 'bhimasena',
#   'text': 'divodaasa, king of the kaashis, son of bhimasena or sudeva.'},
#  {'head': 'divodaasa',
#   'relation': 'son of',
#   'tail': 'sudeva',
#   'text': 'divodaasa, king of the kaashis, son of bhimasena or sudeva.'},
#  {'head': 'king',
#   'relation': 'son of',
#   'tail': 'subala',
#   'text': 'kotikaasya introduced himself to draupadi and showed her the trigarta king kshemankara, and the son of the king of the kulindas, and the son of subala  of the race of ikshvaaku he said that jayadratha was there at the head of, chariots, etc followed by twelve sauvira princes as his standard bearers, and his brothers.'},
#  {'head': 'dravina',
#   'relation': 'son of',
#   'tail': 'the vasu dhara',
#   'text': 'dravina, son of the vasu dhara.'},
#  {'head': 'drona',
#   'relation': 'son of',
#   'tail': 'bharadvaaja',
#   'text': 'drona, the preceptor of the dhaartaraashtras and the paandavas, dhrishtadyumna, etc son of bharadvaaja, husband of kripi, and father of ashvatthaaman.'},
#  {'head': 'drona',
#   'relation': 'son of',
#   'tail': 'husband',
#   'text': 'drona, the preceptor of the dhaartaraashtras and the paandavas, dhrishtadyumna, etc son of bharadvaaja, husband of kripi, and father of ashvatthaaman.'},
#  {'head': 'shaarngaka',
#   'relation': 'son of',
#   'tail': 'mandapaala',
#   'text': 'drona2, a shaarngaka, a son of mandapaala and jaritaa.'},
#  {'head': 'shaarngaka',
#   'relation': 'son of',
#   'tail': 'jaritaa',
#   'text': 'drona2, a shaarngaka, a son of mandapaala and jaritaa.'},
#  {'head': 'druhyu1',
#   'relation': 'son of',
#   'tail': 'yayaati',
#   'text': 'druhyu1, son of yayaati and sharmishthaa.'},
#  {'head': 'druhyu1',
#   'relation': 'son of',
#   'tail': 'sharmishthaa',
#   'text': 'druhyu1, son of yayaati and sharmishthaa.'},
#  {'head': 'druhyu2',
#   'relation': 'son of',
#   'tail': 'matinaara',
#   'text': 'druhyu2, son of matinaara.'},
#  {'head': 'drupada',
#   'relation': 'son of',
#   'tail': 'prishata',
#   'text': 'drupada, king of the paancaalas, son of prishata, father of dhrishtadyumna, shikhandin, draupadi, etc.'},
#  {'head': 'dridha1',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'dridha1, son of dhritaraashtra.'},
#  {'head': 'dridhaashva',
#   'relation': 'son of',
#   'tail': 'kuvalaashva',
#   'text': 'dridhaashva, son of kuvalaashva.'},
#  {'head': 'dridhahasta',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'dridhahasta, a son of dhritaraashtra.'},
#  {'head': 'dridhakshatra',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'dridhakshatra, a son of dhritaraashtra.'},
#  {'head': 'dridharatha1',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'dridharatha1, a son of dhritaraashtra.'},
#  {'head': 'dridharathaashraya',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'dridharathaashraya, a son of dhritaraashtra.'},
#  {'head': 'dridhasandha',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'dridhasandha, a son of dhritaraashtra.'},
#  {'head': 'dridhasyu',
#   'relation': 'son of',
#   'tail': 'agastya',
#   'text': 'dridhasyu, a rishi, son of agastya and lopaamudraa.'},
#  {'head': 'dridhasyu',
#   'relation': 'son of',
#   'tail': 'lopaamudraa',
#   'text': 'dridhasyu, a rishi, son of agastya and lopaamudraa.'},
#  {'head': 'dridhavarman',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'dridhavarman, a son of dhritaraashtra.'},
#  {'head': 'dridhaayu',
#   'relation': 'son of',
#   'tail': 'pururavas',
#   'text': 'dridhaayu, son of pururavas and urvashi.'},
#  {'head': 'dridhaayu',
#   'relation': 'son of',
#   'tail': 'urvashi',
#   'text': 'dridhaayu, son of pururavas and urvashi.'},
#  {'head': 'dridhaayudha',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'dridhaayudha, a son of dhritaraashtra.'},
#  {'head': 'dushala',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'dushala, a son of dhritaraashtra.'},
#  {'head': 'dushaasana',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'dushaasana, a son of dhritaraashtra                                                                   ʹ, ʹ.'},
#  {'head': 'dusaha1',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'dusaha1, son of dhritaraashtra.'},
#  {'head': 'duraadhana',
#   'relation': 'son of',
#   'tail': 'dhritariaashtra',
#   'text': 'duraadhana, a son of dhritariaashtra.'},
#  {'head': 'duraadhara',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'duraadhara, a son of dhritaraashtra.'},
#  {'head': 'durdhara1',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'durdhara1, a son of dhritaraashtra.'},
#  {'head': 'durdharsha1',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'durdharsha1, a son of dhritaraashtra.'},
#  {'head': 'durdharshana',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'durdharshana, a son of dhritaraashtra.'},
#  {'head': 'durjaya2',
#   'relation': 'son of',
#   'tail': 'shaaradandaayani',
#   'text': 'durjaya2, son of shaaradandaayani.'},
#  {'head': 'durjaya3',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'durjaya3, son of dhritaraashtra.'},
#  {'head': 'durmada',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'durmada, son of dhritaraashtra.'},
#  {'head': 'durmarshana1',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'durmarshana1, son of dhritaraashtra.'},
#  {'head': 'durmukha1',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'durmukha1, son of dhritaraashtra.'},
#  {'head': 'durvigaaha',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'durvigaaha, a son of dhritaraashtra.'},
#  {'head': 'durvimocana',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'durvimocana, a son of dhritaraashtra.'},
#  {'head': 'durvirocana',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'durvirocana, a son of dhritaraashtra.'},
#  {'head': 'duryodhana1',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'duryodhana1, the eldest son of dhritaraashtra and gaandhaari, and the enemy of the paandavas.'},
#  {'head': 'duryodhana1',
#   'relation': 'son of',
#   'tail': 'gaandhaari',
#   'text': 'duryodhana1, the eldest son of dhritaraashtra and gaandhaari, and the enemy of the paandavas.'},
#  {'head': 'dushkarna',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'dushkarna, a son of dhritaraashtra.'},
#  {'head': 'dushparaajaya',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'dushparaajaya, a son of dhritaraashtra.'},
#  {'head': 'dushpradharsha',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'dushpradharsha, a son of dhritaraashtra.'},
#  {'head': 'dushpradharshana',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'dushpradharshana, a son of dhritaraashtra.'},
#  {'head': 'dushpraharsha',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'dushpraharsha, a son of dhritaraashtra.'},
#  {'head': 'dushyanta2',
#   'relation': 'son of',
#   'tail': 'ajamidha',
#   'text': 'dushyanta2, son of ajamidha.'},
#  {'head': 'bali',
#   'relation': 'son of',
#   'tail': 'virocana',
#   'text': 'therefore one evening the rishi baka daalbhya represented to yudhishthira that the kshatriya should always consult with a brahman, as did the asura king bali, the son of virocana, who went to no other tirtha than the brahmans, and then had all his wishes gratified, but who met with destruction when he began to act unjustly towards them.'},
#  {'head': 'kaanyakubja',
#   'relation': 'son of',
#   'tail': 'kushika',
#   'text': 'gaadhi or gaadhin, a king of kaanyakubja, the son of kushika and the father of vishvaamitra and satyavati.'},
#  {'head': 'gaandhaararaajaputra',
#   'relation': 'son of',
#   'tail': 'shakuni',
#   'text': 'gaandhaararaajaputra = the son of shakuni.'},
#  {'head': 'converted',
#   'relation': 'son of',
#   'tail': 'himself',
#   'text': 'sagara was greeted by all the gods and converted the sea into a son of himself, and after a long reign placed his grandson on the throne and ascended to heaven.'},
#  {'head': 'gardabhi',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'gardabhi, a son of vishvaamitra.'},
#  {'head': 'garuda',
#   'relation': 'son of',
#   'tail': 'kashyapa',
#   'text': 'garuda, the son of kashyapa and vinataa, the vehicle of vishnu, or the emblem of his flagstaff.'},
#  {'head': 'garuda',
#   'relation': 'son of',
#   'tail': 'vinataa',
#   'text': 'garuda, the son of kashyapa and vinataa, the vehicle of vishnu, or the emblem of his flagstaff.'},
#  {'head': 'warrior',
#   'relation': 'son of',
#   'tail': 'subala',
#   'text': 'gavaaksha2, a gandhaara warrior, son of subala and brother of shakuni.'},
#  {'head': 'warrior',
#   'relation': 'son of',
#   'tail': 'brother',
#   'text': 'gavaaksha2, a gandhaara warrior, son of subala and brother of shakuni.'},
#  {'head': 'gaya1',
#   'relation': 'son of',
#   'tail': 'amurtarayas',
#   'text': 'gaya1, an ancient king, son of amurtarayas.'},
#  {'head': 'ghatotkaca',
#   'relation': 'son of',
#   'tail': 'hidimbaa',
#   'text': 'ghatotkaca, a raakshasa, son of hidimbaa and bhimasena paandava                             g.'},
#  {'head': 'ghatotkaca',
#   'relation': 'son of',
#   'tail': 'bhimasena',
#   'text': 'ghatotkaca, a raakshasa, son of hidimbaa and bhimasena paandava                             g.'},
#  {'head': 'ghatotkaca',
#   'relation': 'son of',
#   'tail': 'paandava',
#   'text': 'ghatotkaca, a raakshasa, son of hidimbaa and bhimasena paandava                             g.'},
#  {'head': 'ghora2',
#   'relation': 'son of',
#   'tail': 'angiras',
#   'text': 'ghora2, son of angiras.'},
#  {'head': 'suryadatta',
#   'relation': 'son of',
#   'tail': 'viraata',
#   'text': 'his brothers, shataanika and madiraaksha, and the king himself, and suryadatta and shankha, the eldest son of viraata, put on their coats of mail.'},
#  {'head': 'gomukha2',
#   'relation': 'son of',
#   'tail': 'maatali',
#   'text': 'gomukha2, the son of maatali.'},
#  {'head': 'gopati5',
#   'relation': 'son of',
#   'tail': 'shibi',
#   'text': 'gopati5, a son of shibi.'},
#  {'head': 'restored',
#   'relation': 'son of',
#   'tail': 'r.',
#   'text': 'the jackal mentioned that by raamas  slaying the shudra named shambuka, a brahmana child was restored to life similarly the son of r.'},
#  {'head': 'gurubhaara',
#   'relation': 'son of',
#   'tail': 'garuda',
#   'text': 'gurubhaara, a suparna, the son of garuda.'},
#  {'head': 'haihaya1',
#   'relation': 'son of',
#   'tail': 'vatsa',
#   'text': 'haihaya1, a son of vatsa.'},
#  {'head': 'king',
#   'relation': 'son of',
#   'tail': 'arishtaa',
#   'text': 'hamsa2, a gandharva king, the son of arishtaa.'},
#  {'head': 'monkey',
#   'relation': 'son of',
#   'tail': 'vaayu',
#   'text': 'hanumat or hanumat, name of a monkey, the son of vaayu.'},
#  {'head': 'suparna',
#   'relation': 'son of',
#   'tail': 'garuda',
#   'text': 'hari3, a suparna, the son of garuda.'},
#  {'head': 'hari4',
#   'relation': 'son of',
#   'tail': 'akampana',
#   'text': 'hari4, the son of akampana.'},
#  {'head': 'asura',
#   'relation': 'son of',
#   'tail': 'taarakaaksha',
#   'text': 'hari5, an asura, the son of taarakaaksha.'},
#  {'head': 'harsha',
#   'relation': 'son of',
#   'tail': 'dharma',
#   'text': 'harsha, a son of dharma.'},
#  {'head': 'hastin1',
#   'relation': 'son of',
#   'tail': 'the elder dhritaraashtra',
#   'text': 'hastin1, a son of the elder dhritaraashtra.'},
#  {'head': 'hastin2',
#   'relation': 'son of',
#   'tail': 'suhotra',
#   'text': 'hastin2, a son of suhotra.'},
#  {'head': 'havishravas',
#   'relation': 'son of',
#   'tail': 'the elder dhritaraashtra',
#   'text': 'havishravas, a son of the elder dhritaraashtra.'},
#  {'head': 'suparna',
#   'relation': 'son of',
#   'tail': 'garuda',
#   'text': 'hemavarna1, a suparna, the son of garuda.'},
#  {'head': 'hemavarna2',
#   'relation': 'son of',
#   'tail': 'rocamaana',
#   'text': 'hemavarna2, the son of rocamaana.'},
#  {'head': 'hiranyaaksha2',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'hiranyaaksha2, a son of vishvaamitra.'},
#  {'head': 'ishvara7',
#   'relation': 'son of',
#   'tail': 'puru',
#   'text': 'ishvara7, a son of puru.'},
#  {'head': 'king',
#   'relation': 'son of',
#   'tail': 'great grandson of manu',
#   'text': 'ikshvaaku1, an ancient king, the son or great grandson of manu vaivasvata.'},
#  {'head': 'lakshmana',
#   'relation': 'son of',
#   'tail': 'dasharatha',
#   'text': 'ikshvaakunandana1  = lakshmana, the son of dasharatha.'},
#  {'head': 'raama',
#   'relation': 'son of',
#   'tail': 'dasharatha',
#   'text': 'ikshvaakunandana2 = raama, the son of dasharatha.'},
#  {'head': 'hari',
#   'relation': 'son of',
#   'tail': 'akampanapratimavikramaafather',
#   'text': 'hari, the son of akampanapratimavikramaafather of arjunasuryagunodayam, sc.'},
#  {'head': 'indraabha',
#   'relation': 'son of',
#   'tail': 'the elder dhritaraashtra',
#   'text': 'indraabha, son of the elder dhritaraashtra.'},
#  {'head': 'indrajit',
#   'relation': 'son of',
#   'tail': 'raavana',
#   'text': 'indrajit, a raakshasa, son of raavana.'},
#  {'head': 'raama',
#   'relation': 'son of',
#   'tail': 'shishupaala',
#   'text': 'sanjaya commemorated how krishna, dhrishtadyumna, viraata, dhrishta ketu, and the kaikeyas had visited the paandavas in the kaamyaka wood, whose conversations sanjaya had learnt through spies and formerly told dhritaraashtra, sanjaya further related that krishna had consented to become the  charioteer of arjuna  and to assist the paandavas in the battle, together with raama, akrura, gada, shaamba, pradyumna, aahuka, dhrishtadyumna, and the son of shishupaala, and yuyu dhaana, and the kaikeya and paancaala princes and the matsya king, and krishna had declared that yudhishthira should, along with his brothers living at haastinapura, rule the earth.'},
#  {'head': 'raama',
#   'relation': 'son of',
#   'tail': 'yuyu',
#   'text': 'sanjaya commemorated how krishna, dhrishtadyumna, viraata, dhrishta ketu, and the kaikeyas had visited the paandavas in the kaamyaka wood, whose conversations sanjaya had learnt through spies and formerly told dhritaraashtra, sanjaya further related that krishna had consented to become the  charioteer of arjuna  and to assist the paandavas in the battle, together with raama, akrura, gada, shaamba, pradyumna, aahuka, dhrishtadyumna, and the son of shishupaala, and yuyu dhaana, and the kaikeya and paancaala princes and the matsya king, and krishna had declared that yudhishthira should, along with his brothers living at haastinapura, rule the earth.'},
#  {'head': 'indrasena1',
#   'relation': 'son of',
#   'tail': 'the elder parikshit',
#   'text': 'indrasena1, a son of the elder parikshit.'},
#  {'head': 'indrasena2',
#   'relation': 'son of',
#   'tail': 'nala',
#   'text': 'indrasena2, the son of nala and damayanti.'},
#  {'head': 'indrasena2',
#   'relation': 'son of',
#   'tail': 'damayanti',
#   'text': 'indrasena2, the son of nala and damayanti.'},
#  {'head': 'iraavat',
#   'relation': 'son of',
#   'tail': 'arjuna',
#   'text': 'iraavat, a son of arjuna paandava.'},
#  {'head': 'jaabaali',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'jaabaali, a rishi, son of vishvaamitra.'},
#  {'head': 'jaitra',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'jaitra, a son of dhritaraashtra.'},
#  {'head': 'jaleyu',
#   'relation': 'son of',
# ...
#   'text': 'ugrasena4, a son of dhritaraashtra.'},
#  {'head': 'ugrasena5',
#   'relation': 'son of',
#   'tail': 'the elder parikshit',
#   'text': 'ugrasena5, son of the elder parikshit.'},
#  {'head': 'ugrayaayin',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'ugrayaayin, a son of dhritaraashtra.'},
#  {'head': 'ugraayudha1',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'ugraayudha1, a son of dhritaraashtra.'},
#  {'head': 'ujjayana',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'ujjayana, a son of vishvaamitra.'},
#  {'head': 'uluka1',
#   'relation': 'son of',
#   'tail': 'shakuni',
#   'text': 'uluka1, kaitavya, son of shakuni.'},
#  {'head': 'upacitra',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'upacitra, a son of dhritaraashtra.'},
#  {'head': 'upagahana',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'upagahana, son of vishvaamitra.'},
#  {'head': 'upananda2',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'upananda2, a son of dhritaraashtra.'},
#  {'head': 'upanandaka1',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'upanandaka1, a son of dhritaraashtra.'},
#  {'head': 'urjayoni',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'urjayoni, a son of vishvaamitra.'},
#  {'head': 'urnanaabha',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'urnanaabha, a son of dhritaraashtra.'},
#  {'head': 'utathya',
#   'relation': 'son of',
#   'tail': 'angiras',
#   'text': 'utathya, a rishi, son of angiras.'},
#  {'head': 'uttara1',
#   'relation': 'son of',
#   'tail': 'viraata',
#   'text': 'uttara1, son of viraata.'},
#  {'head': 'vaahuli',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'vaahuli, a son of vishvaamitra.'},
#  {'head': 'suparna',
#   'relation': 'son of',
#   'tail': 'garuda',
#   'text': 'vainateya2, a suparna, son of garuda.'},
#  {'head': 'vairaata',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'vairaata, a son of dhritaraashtra.'},
#  {'head': 'vajra1',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'vajra1, son of vishvaamitra.'},
#  {'head': 'vajrashirsha',
#   'relation': 'son of',
#   'tail': 'bhrigu',
#   'text': 'vajrashirsha, a son of bhrigu.'},
#  {'head': 'praagjyotisha',
#   'relation': 'son of',
#   'tail': 'bhagadatta',
#   'text': 'vajradatta, king of praagjyotisha, the son of bhagadatta.'},
#  {'head': 'vajravishkambha',
#   'relation': 'son of',
#   'tail': 'garuda',
#   'text': 'vajravishkambha, a suparna, son of garuda.'},
#  {'head': 'vakshogriva',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'vakshogriva, son of vishvaamitra.'},
#  {'head': 'valgujangha',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'valgujangha, a son of vishvaamitra.'},
#  {'head': 'suparna',
#   'relation': 'son of',
#   'tail': 'garuda',
#   'text': 'vaalmiki2, a suparna, son of garuda.'},
#  {'head': 'suparna',
#   'relation': 'son of',
#   'tail': 'garuda',
#   'text': 'vaamana3, a suparna, son of garuda.'},
#  {'head': 'vandi',
#   'relation': 'son of',
#   'tail': 'varuna',
#   'text': 'vandi or vandin, a suta, son of varuna.'},
#  {'head': 'varcas1',
#   'relation': 'son of',
#   'tail': 'soma',
#   'text': 'varcas1, son of soma.'},
#  {'head': 'varcas3',
#   'relation': 'son of',
#   'tail': 'sucetas',
#   'text': 'varcas3, son of sucetas.'},
#  {'head': 'varcasvin1',
#   'relation': 'son of',
#   'tail': 'varcas',
#   'text': 'varcasvin1, son of varcas.'},
#  {'head': 'name',
#   'relation': 'son of',
#   'tail': 'bhrigu',
#   'text': 'do according to br  name of the sixth son of bhrigu.'},
#  {'head': 'varishtha2',
#   'relation': 'son of',
#   'tail': 'manu',
#   'text': 'varishtha2, son of manu caakshusha.'},
#  {'head': 'vasaati1',
#   'relation': 'son of',
#   'tail': 'the elder janamejaya',
#   'text': 'vasaati1, son of the elder janamejaya.'},
#  {'head': 'rishi',
#   'relation': 'son of',
#   'tail': 'varuna',
#   'text': 'vasishtha, a rishi, son of varuna, one of the saptarshis, husband of arundhati, father of shakti and grandfather of paraashara.'},
#  {'head': 'vasu4',
#   'relation': 'son of',
#   'tail': 'jamadagni',
#   'text': 'vasu4, son of jamadagni.'},
#  {'head': 'vasudeva',
#   'relation': 'son of',
#   'tail': 'shura',
#   'text': 'vasudeva, son of shura, husband of devaki, etc father of krishna, etc.'},
#  {'head': 'king',
#   'relation': 'son of',
#   'tail': 'haryashva',
#   'text': 'vasumanas1, an ancient king, son of haryashva and maadhavi and grandson of yayaati.'},
#  {'head': 'king',
#   'relation': 'son of',
#   'tail': 'maadhavi',
#   'text': 'vasumanas1, an ancient king, son of haryashva and maadhavi and grandson of yayaati.'},
#  {'head': 'king',
#   'relation': 'son of',
#   'tail': 'grandson',
#   'text': 'vasumanas1, an ancient king, son of haryashva and maadhavi and grandson of yayaati.'},
#  {'head': 'king',
#   'relation': 'son of',
#   'tail': 'janaka',
#   'text': 'vasumat5, a king, son of janaka.'},
#  {'head': 'vaataghna',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'vaataghna, a son of vishvaamitra.'},
#  {'head': 'vaatavega1',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'vaatavega1, son of dhritaraashtra   ʹ.'},
#  {'head': 'suparna',
#   'relation': 'son of',
#   'tail': 'garuda',
#   'text': 'vaatavega2, a suparna, son of garuda.'},
#  {'head': 'vaayubala',
#   'relation': 'son of',
#   'tail': 'mankanaka',
#   'text': 'vaayubala, son of mankanaka.'},
#  {'head': 'vaayucakra',
#   'relation': 'son of',
#   'tail': 'mankanaka',
#   'text': 'vaayucakra, son of mankanaka.'},
#  {'head': 'vaayuhan',
#   'relation': 'son of',
#   'tail': 'mankanaka',
#   'text': 'vaayuhan, son of mankanaka.'},
#  {'head': 'vaayujvaala',
#   'relation': 'son of',
#   'tail': 'mankanaka',
#   'text': 'vaayujvaala, son of mankanaka.'},
#  {'head': 'vaayumandala',
#   'relation': 'son of',
#   'tail': 'mankanaka',
#   'text': 'vaayumandala, son of mankanaka.'},
#  {'head': 'vaayuretas',
#   'relation': 'son of',
#   'tail': 'mankanaka',
#   'text': 'vaayuretas, son of mankanaka.'},
#  {'head': 'vaayuvega3',
#   'relation': 'son of',
#   'tail': 'mankanaka',
#   'text': 'vaayuvega3, son of mankanaka.'},
#  {'head': 'vibhu2',
#   'relation': 'son of',
#   'tail': 'bhrigu',
#   'text': 'vibhu2, the sixth son of bhrigu.'},
#  {'head': 'vibhuti',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'vibhuti, son of vishvaamitra.'},
#  {'head': 'vicitravirya',
#   'relation': 'son of',
#   'tail': 'shaantanu',
#   'text': 'vicitravirya, a king, son of shaantanu and satyavati.'},
#  {'head': 'vicitravirya',
#   'relation': 'son of',
#   'tail': 'satyavati',
#   'text': 'vicitravirya, a king, son of shaantanu and satyavati.'},
#  {'head': 'suparna',
#   'relation': 'son of',
#   'tail': 'garuda',
#   'text': 'vishaalaaksha3, a suparna, son of garuda.'},
#  {'head': 'vishvaamitra',
#   'relation': 'son of',
#   'tail': 'gaadhi',
#   'text': 'vishvaamitra, a rishi, son of gaadhi bis.'},
#  {'head': 'vishvarupa2',
#   'relation': 'son of',
#   'tail': 'tvashtri',
#   'text': 'vishvarupa2, son of tvashtri.'},
#  {'head': 'vishvaavasu2',
#   'relation': 'son of',
#   'tail': 'jamadagni',
#   'text': 'vishvaavasu2, son of jamadagni.'},
#  {'head': 'viduratha1',
#   'relation': 'son of',
#   'tail': 'kuru',
#   'text': 'viduratha1, son of kuru and shubhaangi.'},
#  {'head': 'viduratha1',
#   'relation': 'son of',
#   'tail': 'shubhaangi',
#   'text': 'viduratha1, son of kuru and shubhaangi.'},
#  {'head': 'vijaya5',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'vijaya5, son of dhritaraashtra.'},
#  {'head': 'vikarna1',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'vikarna1, a son of dhritaraashtra.'},
#  {'head': 'vikata1',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'vikata1, son of dhritaraashtra.'},
#  {'head': 'vikataanana',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'vikataanana, son of dhritaraashtra.'},
#  {'head': 'vimsha',
#   'relation': 'son of',
#   'tail': 'ikshvaaku',
#   'text': 'vimsha, son of ikshvaaku.'},
#  {'head': 'vinda3',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'vinda3, son of dhritaraashtra.'},
#  {'head': 'vira2',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'vira2, a son of dhritaraashtra.'},
#  {'head': 'virabaahu1',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'virabaahu1, son of dhritaraashtra.'},
#  {'head': 'viraaja',
#   'relation': 'son of',
#   'tail': 'avikshit',
#   'text': 'viraaja, son of avikshit.'},
#  {'head': 'virajas2',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'virajas2, son of dhritaraashtra.'},
#  {'head': 'virajas3',
#   'relation': 'son of',
#   'tail': 'naaraayana',
#   'text': 'virajas3, a spiritual son of naaraayana.'},
#  {'head': 'virajas4',
#   'relation': 'son of',
#   'tail': 'kavi',
#   'text': 'virajas4, son of kavi.'},
#  {'head': 'viraavin',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'viraavin, a son of dhritaraashtra.'},
#  {'head': 'virocana2',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'virocana2, a son of dhritaraashtra.'},
#  {'head': 'virupa3',
#   'relation': 'son of',
#   'tail': 'angiras',
#   'text': 'virupa3, son of angiras.'},
#  {'head': 'shula',
#   'relation': 'son of',
#   'tail': 'kashyapa',
#   'text': 's incarnations are the following  a boar  yojanas in length  half lion, half man, when he killed the daitya king hiranyakashipu, who attacked him with his shula   the son of kashyapa and aditi, in the form of a dwarf, born, years after the conception, of the hue of rain charged clouds and with bright eyes when he, accompanied by brihaspati, entered the sacrificial assembly of bali, the king of the daanavas, he, in three paces, took in the earth  and gave it to indra  krishna, with conchshell, discus, and mace, aned with the shrivatsa, clad in yellow silken robes, who protects arjuna, riding in the same chariot with him.'},
#  {'head': 'shula',
#   'relation': 'son of',
#   'tail': 'aditi',
#   'text': 's incarnations are the following  a boar  yojanas in length  half lion, half man, when he killed the daitya king hiranyakashipu, who attacked him with his shula   the son of kashyapa and aditi, in the form of a dwarf, born, years after the conception, of the hue of rain charged clouds and with bright eyes when he, accompanied by brihaspati, entered the sacrificial assembly of bali, the king of the daanavas, he, in three paces, took in the earth  and gave it to indra  krishna, with conchshell, discus, and mace, aned with the shrivatsa, clad in yellow silken robes, who protects arjuna, riding in the same chariot with him.'},
#  {'head': 'vishnudharman',
#   'relation': 'son of',
#   'tail': 'garuda',
#   'text': 'vishnudharman, a suparna, son of garuda.'},
#  {'head': 'vitarka',
#   'relation': 'son of',
#   'tail': 'the elder dhritaraashtra',
#   'text': 'vitarka, son of the elder dhritaraashtra.'},
#  {'head': 'vitatya',
#   'relation': 'son of',
#   'tail': 'vihavya',
#   'text': 'vitatya, a brahman, son of vihavya.'},
#  {'head': 'aan',
#   'relation': 'son of',
#   'tail': 'aditi',
#   'text': 'b, to dvitiyajanmany andasamjnitasya maartando aan shraaddhadeva, son of aditi and born from an eggmaartandasya, father of the ashvins who came out of the nostrils of his wife sanjnaa.'},
#  {'head': 'aan',
#   'relation': 'son of',
#   'tail': 'born',
#   'text': 'b, to dvitiyajanmany andasamjnitasya maartando aan shraaddhadeva, son of aditi and born from an eggmaartandasya, father of the ashvins who came out of the nostrils of his wife sanjnaa.'},
#  {'head': 'vivimsha1',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'vivimsha1, son of dhritaraashtra.'},
#  {'head': 'prince',
#   'relation': 'son of',
#   'tail': 'vimsha',
#   'text': 'vivimsha2, a prince, son of vimsha.'},
#  {'head': 'vivimshati',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'vivimshati, a son of dhritaraashtra.'},
#  {'head': 'vivitsu',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'vivitsu, a son of dhritaraashtra.'},
#  {'head': 'vrajana',
#   'relation': 'son of',
#   'tail': 'ajamidha',
#   'text': 'vrajana, son of ajamidha.'},
#  {'head': 'vrindaaraka',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'vrindaaraka, a son of dhritaraashtra.'},
#  {'head': 'prince',
#   'relation': 'son of',
#   'tail': 'subala',
#   'text': 'vrishaka1, a gandhaara prince, son of subala, brother of acala and shakuni, and brother in law of dhritaraashtra.'},
#  {'head': 'prince',
#   'relation': 'son of',
#   'tail': 'brother',
#   'text': 'vrishaka1, a gandhaara prince, son of subala, brother of acala and shakuni, and brother in law of dhritaraashtra.'},
#  {'head': 'vrishasena3',
#   'relation': 'son of',
#   'tail': 'karna',
#   'text': 'vrishasena3, son of karna     ʹ.'},
#  {'head': 'mhbhr',
#   'relation': 'son of',
#   'tail': 'paraashara',
#   'text': 'vyaasa, a rishi, the supposed compiler of mhbhr son of paraashara and satyavati, father of shuka, and, with the wives of vicitravirya, of dhritaraashtra, paandu, and vidura his proper name is krishna, and on account of his being born on an island  he is called dvaipaayana  and krishna dvaipaayana  he arranged the vedas.'},
#  {'head': 'mhbhr',
#   'relation': 'son of',
#   'tail': 'satyavati',
#   'text': 'vyaasa, a rishi, the supposed compiler of mhbhr son of paraashara and satyavati, father of shuka, and, with the wives of vicitravirya, of dhritaraashtra, paandu, and vidura his proper name is krishna, and on account of his being born on an island  he is called dvaipaayana  and krishna dvaipaayana  he arranged the vedas.'},
#  {'head': 'vyudhoraska',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'vyudhoraska, son of dhritaraashtra.'},
#  {'head': 'vyudhoru',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'vyudhoru, son of dhritaraashtra.'},
#  {'head': 'yashodhara',
#   'relation': 'son of',
#   'tail': 'krishna',
#   'text': 'yashodhara, son of krishna and rukmini.'},
#  {'head': 'yashodhara',
#   'relation': 'son of',
#   'tail': 'rukmini',
#   'text': 'yashodhara, son of krishna and rukmini.'},
#  {'head': 'yadu1',
#   'relation': 'son of',
#   'tail': 'yayaati',
#   'text': 'yadu1, son of yayaati and ancestor of the yadus.'},
#  {'head': 'yadu1',
#   'relation': 'son of',
#   'tail': 'ancestor',
#   'text': 'yadu1, son of yayaati and ancestor of the yadus.'},
#  {'head': 'yama1',
#   'relation': 'son of',
#   'tail': 'vivasvat',
#   'text': 'yama1, lord of the spirits of the dead, son of vivasvat, often identified with dharma.'},
#  {'head': 'yamaduta',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'yamaduta, a son of vishvaamitra.'},
#  {'head': 'varuna',
#   'relation': 'son of',
#   'tail': 'aditi',
#   'text': 'dd in the y varuna, the son of aditi, had in days of yore, performed the raajasuya sacrifice having subjugated both men and celestials and g.'},
#  {'head': 'yati1',
#   'relation': 'son of',
#   'tail': 'nahusha',
#   'text': 'yati1, son of nahusha.'},
#  {'head': 'yati2',
#   'relation': 'son of',
#   'tail': 'vishvaamitra',
#   'text': 'yati2, a son of vishvaamitra.'},
#  {'head': 'yaudheya',
#   'relation': 'son of',
#   'tail': 'yudhishthira',
#   'text': 'yaudheya, son of yudhishthira and devikaa.'},
#  {'head': 'yaudheya',
#   'relation': 'son of',
#   'tail': 'devikaa',
#   'text': 'yaudheya, son of yudhishthira and devikaa.'},
#  {'head': 'yauyudhaani',
#   'relation': 'son of',
#   'tail': 'saatyaki',
#   'text': 'yauyudhaani, son of saatyaki.'},
#  {'head': 'yavakrita',
#   'relation': 'son of',
#   'tail': 'bharadvaaja',
#   'text': 'yavakrita, a rishi, son of bharadvaaja.'},
#  {'head': 'yayaati',
#   'relation': 'son of',
#   'tail': 'nahusha',
#   'text': 'yayaati, an ancient king, son of nahusha  bis.'},
#  {'head': 'ajaatashatru',
#   'relation': 'son of',
#   'tail': 'paandu',
#   'text': 'yudhishthira paandava, also named ajaatashatru and dharmaraaja, eldest son of paandu and kunti.'},
#  {'head': 'ajaatashatru',
#   'relation': 'son of',
#   'tail': 'kunti',
#   'text': 'yudhishthira paandava, also named ajaatashatru and dharmaraaja, eldest son of paandu and kunti.'},
#  {'head': 'yuyutsu',
#   'relation': 'son of',
#   'tail': 'dhritaraashtra',
#   'text': 'yuyutsu, son of dhritaraashtra and a vaishyaa among eleven sons of dhritaraashtra who are mahaarathasamshaavat.'}]

# %%
import pickle

with open('SON.pkl','wb') as f:
    pickle.dump(rels,f)
